# %% [markdown]
# # Digit Classifier

# %% [markdown]
# In this playbook, you can generate and train a model that can classify between 10 different classes. These classes are the digits. If you want you can classify between any two class of digits or other multi-class classificaiton.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from torchmetrics import ConfusionMatrix

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
from torch.optim import lr_scheduler

from torch.autograd import Variable

from torch.utils.data import DataLoader, Dataset

from torchvision import transforms
from torchvision.utils import make_grid

import math
import random

from PIL import Image, ImageOps, ImageEnhance
import numbers

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Explore and Import the Data

# %% [markdown]
# Import dataframes seperatley, then merge and shuffle them

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively
_train = pd.read_csv('./train.csv')
_test = pd.read_csv('./test_labeled.csv', sep=';')

# %%
def extract_DF(df, label):
    temp = df.loc[df['label'] < label+1]
    return temp.loc[temp['label'] > label-1]

# %%
# test datasets

class1 = 6
class2 = 8
class3 = 9
a1 = extract_DF(_train, class1)
a2 = extract_DF(_train, class2)
a3 = extract_DF(_train, class3)

train_df = pd.concat([a1, a2, a3])
train_df = train_df.sample(frac=1).reset_index(drop=True)

# train datasets
e1 = extract_DF(_test, class1)
e2 = extract_DF(_test, class2)
e3 = extract_DF(_test, class3)

test_df = pd.concat([e1, e2, e3])
test_df = test_df.sample(frac=1).reset_index(drop=True)

# %%
train_df = _train
test_df = _test

# %% [markdown]
# Here print the first 10 rows of these datasets to verify that they are corectly generated

# %%
print("Train:", train_df.iloc[:10,0])
print("Test:", test_df.iloc[:10,0])
# Out:
# Train: 0    1
# 1    0
# 2    1
# 3    4
# 4    0
# 5    0
# 6    7
# 7    3
# 8    5
# 9    3
# Name: label, dtype: int64
# Test: 0    2
# 1    0
# 2    9
# 3    9
# 4    3
# 5    7
# 6    0
# 7    3
# 8    0
# 9    3
# Name: label, dtype: int64

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively

n_train = len(train_df)
n_pixels = len(train_df.columns) - 1
n_class = len(set(train_df['label']))

print("Number of training samples:",n_train)
print('Number of training pixels: ', n_pixels)
print('Number of classes: ', n_class)
# Out:
# Number of training samples: 42000
# Number of training pixels:  784
# Number of classes:  10

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively

n_test = len(test_df)
n_pixels = len(test_df.columns) - 1
n_class = len(set(test_df['label']))

print("Number of training samples:",n_test)
print('Number of training pixels: ', n_pixels)
print('Number of classes: ', n_class)
# Out:
# Number of training samples: 28000
# Number of training pixels:  784
# Number of classes:  10

# %% [markdown]
# ## Display Some Images

# %%
def dispImage(df, im):
    grid = make_grid(torch.Tensor((df.iloc[im, 1:].to_numpy()/255.).reshape((-1, 28, 28))).unsqueeze(1), nrow=7)
    plt.rcParams['figure.figsize'] = (32, 150)
    plt.imshow(grid.numpy().transpose((1,2,0)))
    plt.axis('off')

# %%
random_sel = np.random.randint(n_train, size=14)
ten = range(10)

dispImage(train_df, random_sel)
print(*list(train_df.iloc[random_sel, 0].values), sep = ', ')
# Out:
# 9, 0, 6, 6, 0, 6, 1, 5, 2, 9, 5, 5, 7, 0

# %% [markdown]
# ## Distribution of the Classes among Datasets

# %%
def showHistogram(df):
    plt.rcParams['figure.figsize'] = (8, 5)
    plt.bar(df['label'].value_counts().index, df['label'].value_counts())
    plt.xticks(np.arange(10))
    plt.xlabel('Class', fontsize=16)
    plt.ylabel('Count', fontsize=16)
    plt.grid('on', axis='y')

showHistogram(train_df) # Blue si train
showHistogram(test_df) # Orange is test
print("Shape of the train_df is: ", train_df.shape)
print("Shape of the test_df is: ", test_df.shape)
# Out:
# Shape of the train_df is:  (42000, 785)
# Shape of the test_df is:  (28000, 785)

# %% [markdown]
# ## Dataloader Class Definiton

# %%
class MNIST_data(Dataset):
    """MNIST dtaa set"""
    
    
    
    def __init__(self, 
                 df_, #file_path, 
                 sep=',', 
                 isTest=False,
                 transform = transforms.Compose([transforms.ToPILImage(), transforms.ToTensor(), 
                     transforms.Normalize(mean=(0.5,), std=(0.5,))])
                ):
        
        df = df_ #pd.read_csv(file_path, sep=sep)
        self.df = df_
        
        if isTest:
            # test data
            self.X = df.iloc[:,1:].values.reshape((-1,28,28)).astype(np.uint8)[:,:,:,None]
            self.y = None
        else:
            # training data
            self.X = df.iloc[:,1:].values.reshape((-1,28,28)).astype(np.uint8)[:,:,:,None]
            self.y = torch.from_numpy(df.iloc[:,0].values)
            
        self.transform = transform
    
    def __len__(self):
        return len(self.X)
    
    def get_labels(self):
        return df.iloc[:,0]

    def __getitem__(self, idx):
        if self.y is not None:
            return self.transform(self.X[idx]), self.y[idx]
        else:
            return self.transform(self.X[idx])

# %% [markdown]
# ## Random Rotation

# %%
class RandomRotation(object):
    """
    https://github.com/pytorch/vision/tree/master/torchvision/transforms
    Rotate the image by angle.
    Args:
        degrees (sequence or float or int): Range of degrees to select from.
            If degrees is a number instead of sequence like (min, max), the range of degrees
            will be (-degrees, +degrees).
        resample ({PIL.Image.NEAREST, PIL.Image.BILINEAR, PIL.Image.BICUBIC}, optional):
            An optional resampling filter.
            See http://pillow.readthedocs.io/en/3.4.x/handbook/concepts.html#filters
            If omitted, or if the image has mode "1" or "P", it is set to PIL.Image.NEAREST.
        expand (bool, optional): Optional expansion flag.
            If true, expands the output to make it large enough to hold the entire rotated image.
            If false or omitted, make the output image the same size as the input image.
            Note that the expand flag assumes rotation around the center and no translation.
        center (2-tuple, optional): Optional center of rotation.
            Origin is the upper left corner.
            Default is the center of the image.
    """

    def __init__(self, degrees, resample=False, expand=False, center=None):
        if isinstance(degrees, numbers.Number):
            if degrees < 0:
                raise ValueError("If degrees is a single number, it must be positive.")
            self.degrees = (-degrees, degrees)
        else:
            if len(degrees) != 2:
                raise ValueError("If degrees is a sequence, it must be of len 2.")
            self.degrees = degrees

        self.resample = resample
        self.expand = expand
        self.center = center

    @staticmethod
    def get_params(degrees):
        """Get parameters for ``rotate`` for a random rotation.
        Returns:
            sequence: params to be passed to ``rotate`` for random rotation.
        """
        angle = np.random.uniform(degrees[0], degrees[1])

        return angle

    def __call__(self, img):
        """
            img (PIL Image): Image to be rotated.
        Returns:
            PIL Image: Rotated image.
        """
        
        def rotate(img, angle, resample=False, expand=False, center=None):
            """Rotate the image by angle and then (optionally) translate it by (n_columns, n_rows)
            Args:
            img (PIL Image): PIL Image to be rotated.
            angle ({float, int}): In degrees degrees counter clockwise order.
            resample ({PIL.Image.NEAREST, PIL.Image.BILINEAR, PIL.Image.BICUBIC}, optional):
            An optional resampling filter.
            See http://pillow.readthedocs.io/en/3.4.x/handbook/concepts.html#filters
            If omitted, or if the image has mode "1" or "P", it is set to PIL.Image.NEAREST.
            expand (bool, optional): Optional expansion flag.
            If true, expands the output image to make it large enough to hold the entire rotated image.
            If false or omitted, make the output image the same size as the input image.
            Note that the expand flag assumes rotation around the center and no translation.
            center (2-tuple, optional): Optional center of rotation.
            Origin is the upper left corner.
            Default is the center of the image.
            """
                
            return img.rotate(angle, resample, expand, center)

        angle = self.get_params(self.degrees)

        return rotate(img, angle, self.resample, self.expand, self.center)

# %% [markdown]
# ## Random Shift

# %%
class RandomShift(object):
    def __init__(self, shift):
        self.shift = shift
        
    @staticmethod
    def get_params(shift):
        """Get parameters for ``rotate`` for a random rotation.
        Returns:
            sequence: params to be passed to ``rotate`` for random rotation.
        """
        hshift, vshift = np.random.uniform(-shift, shift, size=2)

        return hshift, vshift 
    def __call__(self, img):
        hshift, vshift = self.get_params(self.shift)
        
        return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)

# %% [markdown]
# ## Define the Datasets and Dataloaders

# %%
batch_size = 64

train_dataset = MNIST_data(train_df, transform= transforms.Compose(
                            [transforms.ToPILImage(), RandomRotation(degrees=20), RandomShift(3),
                             transforms.ToTensor(), transforms.Normalize(mean=(0.5,), std=(0.5,))]))
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, shuffle=True)




test_dataset = MNIST_data(test_df, sep=';', isTest=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=batch_size, shuffle=False)

train_x_dataset = MNIST_data(train_df, isTest=True)
train_x_loader = torch.utils.data.DataLoader(dataset=train_x_dataset, batch_size=batch_size, shuffle=False)


test_y_dataset = MNIST_data(test_df, sep=';')
test_y_loader = torch.utils.data.DataLoader(dataset=test_y_dataset, batch_size=batch_size, shuffle=True)

# %%
dispImage(train_df, np.arange(14))
    
print(*list(train_df.iloc[:14, 0].values), sep = ', ')
print(*list(train_dataset.df.iloc[:14,0].values), sep = ', ')
# Out:
# 1, 0, 1, 4, 0, 0, 7, 3, 5, 3, 8, 9, 1, 3
# 1, 0, 1, 4, 0, 0, 7, 3, 5, 3, 8, 9, 1, 3

# %% [markdown]
# ## Demonstration of Random Rotation & Shift

# %%
rotate = RandomRotation(20)
shift = RandomShift(3)
composed = transforms.Compose([RandomRotation(20),
                               RandomShift(3)])

# Apply each of the above transforms on sample.
fig = plt.figure()
sample = transforms.ToPILImage()(train_df.iloc[65,1:].values.reshape((28,28)).astype(np.uint8)[:,:,None])
for i, tsfrm in enumerate([rotate, shift, composed]):
    transformed_sample = tsfrm(sample)

    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(tsfrm).__name__)
    ax.imshow(np.reshape(np.array(list(transformed_sample.getdata())), (-1,28)), cmap='gray')    

plt.show()
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_5606/2105636642.py:17: DeprecationWarning: AFFINE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transform.AFFINE instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_5606/2105636642.py:17: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)

# %% [markdown]
# ## Define the Neural Network

# %%
class Net(nn.Module):    
    def __init__(self):
        super(Net, self).__init__()
          
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
          
        self.classifier = nn.Sequential(
            nn.Dropout(p = 0.5),
            nn.Linear(64 * 7 * 7, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.5),
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.5),
            nn.Linear(512, 10),
        )
          
        for m in self.features.children():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        for m in self.classifier.children():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform(m.weight)
            elif isinstance(m, nn.BatchNorm1d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
                

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        
        return x

# %% [markdown]
# ## Initialize the Model

# %%
model = Net()

optimizer = optim.Adam(model.parameters(), lr=0.003) #0.003

criterion = nn.CrossEntropyLoss()

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_5606/4122321177.py:45: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(m.weight)

# %% [markdown]
# ## Training Algorithm

# %%
loss_values = []
def train(epoch):
    model.train()

    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        
        val = F.cross_entropy(output, target, size_average=False).data
        loss_values.append(val)
        
        loss.backward()
        optimizer.step()
        
        if (batch_idx + 1)% 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, (batch_idx + 1) * len(data), len(train_loader.dataset),
                100. * (batch_idx + 1) / len(train_loader), loss.data))
    
    
    exp_lr_scheduler.step()

# %% [markdown]
# ## Evaluation of Training

# %%
def evaluate(data_loader):
    model.eval()
    loss = 0
    correct = 0
    
    for data, target in data_loader:
        data, target = Variable(data), Variable(target)
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        output = model(data)
        
        loss += F.cross_entropy(output, target, size_average=False).data

        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        
    loss /= len(data_loader.dataset)
        
    print('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.3f}%)\n'.format(
        loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))

# %% [markdown]
# ## Train the Model

# %%
n_epochs = 1

for epoch in range(n_epochs):
    train(epoch)
    evaluate(train_loader)
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_5606/2105636642.py:17: DeprecationWarning: AFFINE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transform.AFFINE instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_5606/2105636642.py:17: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /Users/ilerisoy/opt/anaconda3/envs/ml/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
#
# Train Epoch: 0 [32000/42000 (76%)]	Loss: 0.150143
# Train Epoch: 0 [32640/42000 (78%)]	Loss: 0.124335
# Train Epoch: 0 [33280/42000 (79%)]	Loss: 0.107719
# Train Epoch: 0 [33920/42000 (81%)]	Loss: 0.147225
# Train Epoch: 0 [34560/42000 (82%)]	Loss: 0.362322
# Train Epoch: 0 [35200/42000 (84%)]	Loss: 0.088288
# Train Epoch: 0 [35840/42000 (85%)]	Loss: 0.265482
# Train Epoch: 0 [36480/42000 (87%)]	Loss: 0.198913
# Train Epoch: 0 [37120/42000 (88%)]	Loss: 0.186886
# Train Epoch: 0 [37760/42000 (90%)]	Loss: 0.189033
# Train Epoch: 0 [38400/42000 (91%)]	Loss: 0.213707
# Train Epoch: 0 [39040/42000 (93%)]	Loss: 0.186159
# Train Epoch: 0 [39680/42000 (94%)]	Loss: 0.223484
# Train Epoch: 0 [40320/42000 (96%)]	Loss: 0.343607
# Train Epoch: 0 [40960/42000 (97%)]	Loss: 0.157363
# Train Epoch: 0 [41600/42000 (99%)]	Loss: 0.291506
#
# Average loss: 0.1042, Accuracy: 40657/42000 (96.802%)

# %%
plt.plot(loss_values)
plt.ylabel('Loss')
plt.show()

print(loss_values[0:5], loss_values[len(loss_values)-5:])
print(len(loss_values))
# Out:
# [tensor(200.2444), tensor(178.1806), tensor(167.8973), tensor(170.9953), tensor(156.6471)] [tensor(2.2635), tensor(13.1888), tensor(6.7831), tensor(20.3970), tensor(1.2365)]
# 657

# %% [markdown]
# ## Prediction Algorithm

# %%
train_prob = []
test_prob = []
def prediciton(data_loader, df_type):
    model.eval()
    test_pred = torch.LongTensor()
    
    for i, data in enumerate(data_loader):
        data = Variable(data)
        if torch.cuda.is_available():
            data = data.cuda()
            
        output = model(data)
        
        batch_prob = F.softmax(output, dim=1)
        if df_type == "train":
            for i in range(len(batch_prob)):
                train_prob.append(batch_prob[i])
        elif df_type == "test":
            for i in range(len(batch_prob)):
                test_prob.append(batch_prob[i])
        else:
            print("Wrong df type is given...")
            return 0
        pred = output.cpu().data.max(1, keepdim=True)[1]
        test_pred = torch.cat((test_pred, pred), dim=0)
        
    return test_pred

# %%
train_pred = prediciton(train_x_loader, "train")

# %%
test_pred = prediciton(test_loader, "test")

# %% [markdown]
# ## Function to Get the Confidence Values

# %%
def getProbs(rawProbs):
    temp = []
    
    for i in range(len(rawProbs)):
        temp.append(rawProbs[i].detach().numpy())

    return temp

train_probs = getProbs(train_prob)
test_probs = getProbs(test_prob)

# %%
item = 0
print(train_probs[item][class1])
print(test_probs[item][class1])
# Out:
# 0.00012923022
# 1.198606e-09

# %% [markdown]
# # Training Prediction

# %%
train_prediction_df = pd.DataFrame(np.c_[np.arange(1, len(train_dataset)+1)[:,None], train_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# Make a numpay array by predcited labels
train_predictions = train_prediction_df.iloc[:,1].to_numpy()
train_labels = train_df.iloc[:,0].to_numpy()
print(len(train_predictions), train_predictions[:10], train_labels[:10])
# Out:
# 42000 [1 0 1 4 0 0 7 3 5 3] [1 0 1 4 0 0 7 3 5 3]

# %%
train_predictions = train_prediction_df.iloc[:, 1].to_numpy()

count = 0
train_index = []

for i in range(len(train_predictions)):
    if train_dataset.df.iloc[i,0] == train_predictions[i]:
        continue
    else:
        count +=1
        train_index.append(i)
        print("Label is: ", train_dataset.y.numpy()[i], "Predcition is: ", train_predictions[i], "index is: ", i)
print(count)
# Out:
# Label is:  1 Predcition is:  5 index is:  60
# Label is:  9 Predcition is:  7 index is:  95
# Label is:  5 Predcition is:  8 index is:  125
# Label is:  7 Predcition is:  2 index is:  132
# Label is:  1 Predcition is:  4 index is:  191
# Label is:  5 Predcition is:  9 index is:  453
# Label is:  5 Predcition is:  3 index is:  460
# Label is:  1 Predcition is:  2 index is:  622
# Label is:  9 Predcition is:  0 index is:  641
# Label is:  7 Predcition is:  2 index is:  679
# Label is:  2 Predcition is:  7 index is:  719
# Label is:  9 Predcition is:  8 index is:  799
# Label is:  7 Predcition is:  9 index is:  856
# Label is:  7 Predcition is:  2 index is:  884
# Label is:  1 Predcition is:  8 index is:  897
# Label is:  6 Predcition is:  5 index is:  1143
# Label is:  4 Predcition is:  9 index is:  1179
# Label is:  4 Predcition is:  8 index is:  1224
# Label is:  5 Predcition is:  6 index is:  1591
# Label is:  2 Predcition is:  7 index is:  1615
# Label is:  8 Predcition is:  7 index is:  1628
# Label is:  1 Predcition is:  7 index is:  1716
# Label is:  2 Predcition is:  7 index is:  1866
# Label is:  1 Predcition is:  3 index is:  1883
# Label is:  6 Predcition is:  5 index is:  1914
# Label is:  9 Predcition is:  7 index is:  1948
# Label is:  1 Predcition is:  5 index is:  1979
# Label is:  5 Predcition is:  3 index is:  2067
# Label is:  0 Predcition is:  2 index is:  2143
# Label is:  1 Predcition is:  3 index is:  2284
# Label is:  1 Predcition is:  7 index is:  2316
# Label is:  5 Predcition is:  3 index is:  2335
# Label is:  0 Predcition is:  6 index is:  2381
# Label is:  6 Predcition is:  0 index is:  2400
# Label is:  5 Predcition is:  8 index is:  2453
# Label is:  2 Predcition is:  4 index is:  2541
# Label is:  0 Predcition is:  2 index is:  2618
# Label is:  8 Predcition is:  2 index is:  2628
# Label is:  4 Predcition is:  9 index is:  2816
# Label is:  3 Predcition is:  8 index is:  2874
# Label is:  0 Predcition is:  9 index is:  2940
# Label is:  7 Predcition is:  2 index is:  2981
# Label is:  0 Predcition is:  9 index is:  3023
# Label is:  9 Predcition is:  4 index is:  3097
# Label is:  6 Predcition is:  8 index is:  3184
# Label is:  3 Predcition is:  2 index is:  3278
# Label is:  8 Predcition is:  2 index is:  3409
# Label is:  5 Predcition is:  3 index is:  3450
# Label is:  8 Predcition is:  2 index is:  3521
# Label is:  6 Predcition is:  8 index is:  3593
# Label is:  5 Predcition is:  8 index is:  3621
# Label is:  5 Predcition is:  3 index is:  3672
# Label is:  9 Predcition is:  7 index is:  3715
# Label is:  5 Predcition is:  9 index is:  3748
# Label is:  5 Predcition is:  3 index is:  3773
# Label is:  1 Predcition is:  8 index is:  3783
# Label is:  7 Predcition is:  2 index is:  7975
# Label is:  8 Predcition is:  2 index is:  7992
# Label is:  0 Predcition is:  8 index is:  8062
# Label is:  0 Predcition is:  9 index is:  8100
# Label is:  1 Predcition is:  7 index is:  8147
# Label is:  3 Predcition is:  8 index is:  8169
# Label is:  9 Predcition is:  7 index is:  8260
# Label is:  4 Predcition is:  9 index is:  8388
# Label is:  7 Predcition is:  2 index is:  8415
# Label is:  9 Predcition is:  7 index is:  8616
# Label is:  1 Predcition is:  2 index is:  8631
# Label is:  8 Predcition is:  7 index is:  8641
# Label is:  6 Predcition is:  8 index is:  8785
# Label is:  2 Predcition is:  8 index is:  8825
# Label is:  1 Predcition is:  8 index is:  8942
# Label is:  4 Predcition is:  9 index is:  8960
# Label is:  7 Predcition is:  2 index is:  9007
# Label is:  3 Predcition is:  2 index is:  9051
# Label is:  5 Predcition is:  3 index is:  9155
# Label is:  2 Predcition is:  4 index is:  9162
# Label is:  4 Predcition is:  9 index is:  9257
# Label is:  4 Predcition is:  6 index is:  9303
# Label is:  7 Predcition is:  2 index is:  9461
# Label is:  6 Predcition is:  5 index is:  9472
# Label is:  8 Predcition is:  2 index is:  9501
# Label is:  4 Predcition is:  7 index is:  9619
# Label is:  8 Predcition is:  2 index is:  9794
# Label is:  5 Predcition is:  8 index is:  9995
# Label is:  3 Predcition is:  8 index is:  10299
# Label is:  5 Predcition is:  3 index is:  10328
# Label is:  1 Predcition is:  8 index is:  10353
# Label is:  4 Predcition is:  9 index is:  10455
# Label is:  2 Predcition is:  7 index is:  10644
# Label is:  3 Predcition is:  2 index is:  10700
# Label is:  5 Predcition is:  3 index is:  10709
# Label is:  9 Predcition is:  7 index is:  10710
# Label is:  8 Predcition is:  9 index is:  10712
# Label is:  5 Predcition is:  6 index is:  10803
# Label is:  9 Predcition is:  4 index is:  11001
# Label is:  5 Predcition is:  9 index is:  11037
# Label is:  9 Predcition is:  4 index is:  11169
# Label is:  8 Predcition is:  2 index is:  11188
# Label is:  1 Predcition is:  7 index is:  11246
# Label is:  8 Predcition is:  9 index is:  11340
# Label is:  1 Predcition is:  7 index is:  11406
# Label is:  8 Predcition is:  9 index is:  11418
# Label is:  7 Predcition is:  2 index is:  11452
# Label is:  5 Predcition is:  7 index is:  11501
# Label is:  5 Predcition is:  7 index is:  11509
# Label is:  5 Predcition is:  3 index is:  11524
# Label is:  3 Predcition is:  8 index is:  11593
# Label is:  5 Predcition is:  3 index is:  11693
# Label is:  9 Predcition is:  7 index is:  11714
# Label is:  5 Predcition is:  8 index is:  11750
# Label is:  1 Predcition is:  2 index is:  11811
# Label is:  7 Predcition is:  2 index is:  11833
# Label is:  4 Predcition is:  8 index is:  11942
# Label is:  0 Predcition is:  2 index is:  11987
# Label is:  2 Predcition is:  3 index is:  12111
# Label is:  5 Predcition is:  8 index is:  12321
# Label is:  6 Predcition is:  5 index is:  12388
# Label is:  6 Predcition is:  5 index is:  12429
# Label is:  5 Predcition is:  6 index is:  12518
# Label is:  8 Predcition is:  2 index is:  40868
# Label is:  0 Predcition is:  8 index is:  40900
# Label is:  2 Predcition is:  0 index is:  40976
# Label is:  1 Predcition is:  2 index is:  41106
# Label is:  5 Predcition is:  6 index is:  41172
# Label is:  8 Predcition is:  4 index is:  41229
# Label is:  1 Predcition is:  6 index is:  41275
# Label is:  5 Predcition is:  8 index is:  41294
# Label is:  8 Predcition is:  6 index is:  41299
# Label is:  1 Predcition is:  8 index is:  41333
# Label is:  5 Predcition is:  0 index is:  41454
# Label is:  3 Predcition is:  7 index is:  41492
# Label is:  9 Predcition is:  4 index is:  41640
# Label is:  5 Predcition is:  3 index is:  41679
# Label is:  8 Predcition is:  9 index is:  41700
# Label is:  3 Predcition is:  8 index is:  41884
# Label is:  1 Predcition is:  7 index is:  41923
# Label is:  4 Predcition is:  9 index is:  41943
# 647

# %%
con_train = confusion_matrix(train_dataset.df.iloc[:,0], train_predictions)
# Confusion matrix whose i-th row and j-th column entry indicates the number of samples with 
# true label being i-th class and predicted label being j-th class.
print("\nConfusion Matrix is:\n")
print(con_train,"\n")


# Class 0 is treated as Negative
tn, fp, fn, tp = con_train.ravel()

prec_test = tp/(tp+fp)
sens = tp/(tp+fn)
spec = tn/(tn+fp)

total = tp+tn+fn+fp
acc = (tp+tn)*100/total
print("Accuracy is: %", acc)

print("\nPrecision is: ", prec_test)

print("Sensitivity is: ", sens)
print("Specificity is: ", spec)


print("\nTP: ", tp, "FP: ", fp)
print("FN: ", fn, "  TN: ", tn)
# Out:
# Confusion Matrix is:
#
# [[4086    0   10    1    2    0    9    1   17    6]
#  [   0 4544   38   12   11    3   12   31   33    0]
#  [   2    5 4140    4    3    0    3    8   11    1]
#  [   1    0   11 4300    0    5    0   15   13    6]
#  [   4    2    2    0 4028    0    3    4    2   27]
#  [   2    1    1   45    0 3702   14    2   15   13]
#  [   8    0    1    1    3   16 4089    0   19    0]
#  [   1    0   40    2    4    0    0 4347    1    6]
#  [   2    1   17    1    8    1    1    4 4006   22]
#  [   6    1    0    3   25    2    0   28   12 4111]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [99], in <cell line: 9>()
#       5 print(con_train,"\n")
#       8 # Class 0 is treated as Negative
# ----> 9 tn, fp, fn, tp = con_train.ravel()
#      11 prec_test = tp/(tp+fp)
#      12 sens = tp/(tp+fn)
#
# ValueError: too many values to unpack (expected 4)

# %%
sel = count

for i in range(sel):
    print("Image : ", i)
    print("Confidance values are : ", train_probs[train_index[i]][class1], train_probs[train_index[i]][class2], train_probs[train_index[i]][class3])
    print("Ground Truth is: ", train_df.iloc[train_index[i],0])
    print("Predicted as: ", train_predictions[train_index[i]])

dispImage(train_df, train_index[:sel])

# %% [markdown]
# # Test Prediction

# %%
test_pred_df = pd.DataFrame(np.c_[np.arange(1, len(test_dataset)+1)[:,None], test_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# %%
test_prediction_df = pd.DataFrame(np.c_[np.arange(1, len(test_dataset)+1)[:,None], test_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# Make a numpay array by predcited labels
test_predictions = test_prediction_df.iloc[:,1].to_numpy()
test_labels = test_y_dataset.df.iloc[:,0].to_numpy()
print(len(test_predictions), test_predictions[:10], test_labels[:10])
# Out:
# 28000 [2 0 9 9 3 7 0 3 0 3] [2 0 9 9 3 7 0 3 0 3]

# %%
test_predictions = test_prediction_df.iloc[:, 1].to_numpy()

count2 = 0
test_index = []

for i in range(len(test_predictions)):
    if test_y_dataset.df.iloc[i,0] == test_predictions[i]:
        continue
    else:
        count2 +=1
        test_index.append(i)
        print("Label is: ", test_y_dataset.y.numpy()[i], "Predcition is: ", test_predictions[i], "index is: ", i)
print(count2)
# Out:
# Label is:  6 Predcition is:  8 index is:  44
# Label is:  5 Predcition is:  9 index is:  76
# Label is:  0 Predcition is:  8 index is:  83
# Label is:  9 Predcition is:  8 index is:  109
# Label is:  2 Predcition is:  8 index is:  181
# Label is:  1 Predcition is:  8 index is:  287
# Label is:  6 Predcition is:  5 index is:  409
# Label is:  7 Predcition is:  4 index is:  428
# Label is:  5 Predcition is:  9 index is:  450
# Label is:  1 Predcition is:  6 index is:  460
# Label is:  9 Predcition is:  8 index is:  626
# Label is:  0 Predcition is:  2 index is:  640
# Label is:  4 Predcition is:  8 index is:  647
# Label is:  9 Predcition is:  8 index is:  651
# Label is:  1 Predcition is:  3 index is:  710
# Label is:  6 Predcition is:  0 index is:  725
# Label is:  7 Predcition is:  3 index is:  760
# Label is:  7 Predcition is:  2 index is:  814
# Label is:  0 Predcition is:  8 index is:  831
# Label is:  4 Predcition is:  2 index is:  844
# Label is:  6 Predcition is:  5 index is:  919
# Label is:  9 Predcition is:  8 index is:  1126
# Label is:  4 Predcition is:  9 index is:  1162
# Label is:  1 Predcition is:  6 index is:  1235
# Label is:  1 Predcition is:  3 index is:  1265
# Label is:  4 Predcition is:  8 index is:  1307
# Label is:  6 Predcition is:  5 index is:  1366
# Label is:  2 Predcition is:  7 index is:  1389
# Label is:  7 Predcition is:  9 index is:  1394
# Label is:  9 Predcition is:  8 index is:  1402
# Label is:  5 Predcition is:  8 index is:  1494
# Label is:  2 Predcition is:  3 index is:  1503
# Label is:  1 Predcition is:  8 index is:  1523
# Label is:  2 Predcition is:  3 index is:  1586
# Label is:  1 Predcition is:  6 index is:  1596
# Label is:  6 Predcition is:  5 index is:  1630
# Label is:  9 Predcition is:  8 index is:  1675
# Label is:  4 Predcition is:  9 index is:  1686
# Label is:  5 Predcition is:  0 index is:  1706
# Label is:  7 Predcition is:  2 index is:  1725
# Label is:  5 Predcition is:  3 index is:  1770
# Label is:  1 Predcition is:  6 index is:  1821
# Label is:  5 Predcition is:  9 index is:  1882
# Label is:  6 Predcition is:  0 index is:  1900
# Label is:  6 Predcition is:  8 index is:  1907
# Label is:  5 Predcition is:  3 index is:  1959
# Label is:  7 Predcition is:  2 index is:  2087
# Label is:  2 Predcition is:  6 index is:  2125
# Label is:  7 Predcition is:  2 index is:  2126
# Label is:  0 Predcition is:  2 index is:  2145
# Label is:  7 Predcition is:  2 index is:  2177
# Label is:  1 Predcition is:  8 index is:  7464
# Label is:  7 Predcition is:  4 index is:  7505
# Label is:  9 Predcition is:  8 index is:  7509
# Label is:  3 Predcition is:  8 index is:  7511
# Label is:  0 Predcition is:  6 index is:  7586
# Label is:  3 Predcition is:  8 index is:  7678
# Label is:  4 Predcition is:  8 index is:  7728
# Label is:  0 Predcition is:  6 index is:  7729
# Label is:  8 Predcition is:  2 index is:  7873
# Label is:  7 Predcition is:  2 index is:  7892
# Label is:  6 Predcition is:  8 index is:  7912
# Label is:  5 Predcition is:  3 index is:  7922
# Label is:  3 Predcition is:  9 index is:  7977
# Label is:  7 Predcition is:  2 index is:  7994
# Label is:  7 Predcition is:  2 index is:  8006
# Label is:  4 Predcition is:  2 index is:  8014
# Label is:  7 Predcition is:  3 index is:  8031
# Label is:  3 Predcition is:  8 index is:  8163
# Label is:  7 Predcition is:  2 index is:  8166
# Label is:  6 Predcition is:  5 index is:  8183
# Label is:  5 Predcition is:  8 index is:  8192
# Label is:  7 Predcition is:  9 index is:  8197
# Label is:  5 Predcition is:  3 index is:  8256
# Label is:  5 Predcition is:  8 index is:  8257
# Label is:  5 Predcition is:  8 index is:  8303
# Label is:  6 Predcition is:  0 index is:  8326
# Label is:  7 Predcition is:  2 index is:  8481
# Label is:  7 Predcition is:  9 index is:  8581
# Label is:  9 Predcition is:  4 index is:  8604
# Label is:  7 Predcition is:  9 index is:  8628
# Label is:  9 Predcition is:  8 index is:  8639
# Label is:  0 Predcition is:  2 index is:  8667
# Label is:  0 Predcition is:  5 index is:  8674
# Label is:  7 Predcition is:  2 index is:  8776
# Label is:  5 Predcition is:  8 index is:  8778
# Label is:  5 Predcition is:  3 index is:  8864
# Label is:  7 Predcition is:  9 index is:  8887
# Label is:  5 Predcition is:  3 index is:  8895
# Label is:  7 Predcition is:  9 index is:  8902
# Label is:  7 Predcition is:  8 index is:  8926
# Label is:  5 Predcition is:  3 index is:  8993
# Label is:  7 Predcition is:  2 index is:  8997
# Label is:  1 Predcition is:  2 index is:  9018
# Label is:  7 Predcition is:  2 index is:  9040
# Label is:  0 Predcition is:  2 index is:  9051
# Label is:  9 Predcition is:  8 index is:  9062
# Label is:  7 Predcition is:  8 index is:  9202
# Label is:  6 Predcition is:  0 index is:  9263
# Label is:  5 Predcition is:  3 index is:  9276
# Label is:  3 Predcition is:  7 index is:  9343
# Label is:  7 Predcition is:  9 index is:  9387
# Label is:  9 Predcition is:  8 index is:  9443
# Label is:  4 Predcition is:  8 index is:  9518
# Label is:  5 Predcition is:  1 index is:  9527
# Label is:  6 Predcition is:  5 index is:  9575
# Label is:  1 Predcition is:  8 index is:  9617
# Label is:  1 Predcition is:  6 index is:  9692
# Label is:  9 Predcition is:  8 index is:  9740
# Label is:  3 Predcition is:  7 index is:  9744
# Label is:  7 Predcition is:  2 index is:  9779
# Label is:  3 Predcition is:  5 index is:  9797
# Label is:  7 Predcition is:  2 index is:  9811
# Label is:  7 Predcition is:  2 index is:  9978
# Label is:  6 Predcition is:  8 index is:  9981
# Label is:  9 Predcition is:  8 index is:  19470
# Label is:  2 Predcition is:  0 index is:  19501
# Label is:  6 Predcition is:  5 index is:  19538
# Label is:  7 Predcition is:  2 index is:  19543
# Label is:  9 Predcition is:  8 index is:  19585
# Label is:  1 Predcition is:  8 index is:  19597
# Label is:  4 Predcition is:  6 index is:  19629
# Label is:  1 Predcition is:  4 index is:  19643
# Label is:  7 Predcition is:  3 index is:  19646
# Label is:  7 Predcition is:  2 index is:  19657
# Label is:  2 Predcition is:  6 index is:  19663
# Label is:  0 Predcition is:  8 index is:  19674
# Label is:  7 Predcition is:  2 index is:  19754
# Label is:  4 Predcition is:  6 index is:  19783
# Label is:  7 Predcition is:  2 index is:  19792
# Label is:  7 Predcition is:  2 index is:  19799
# Label is:  7 Predcition is:  2 index is:  19856
# Label is:  3 Predcition is:  8 index is:  19876
# Label is:  9 Predcition is:  8 index is:  19894
# Label is:  0 Predcition is:  8 index is:  19896
# Label is:  2 Predcition is:  8 index is:  19907
# Label is:  5 Predcition is:  8 index is:  20032
# Label is:  7 Predcition is:  2 index is:  20035
# Label is:  7 Predcition is:  2 index is:  20039
# Label is:  1 Predcition is:  9 index is:  20052
# Label is:  9 Predcition is:  4 index is:  20112
# Label is:  6 Predcition is:  8 index is:  20131
# Label is:  5 Predcition is:  9 index is:  20153
# Label is:  1 Predcition is:  8 index is:  20199
# Label is:  8 Predcition is:  5 index is:  20226
# Label is:  1 Predcition is:  5 index is:  20241
# Label is:  1 Predcition is:  8 index is:  20257
# Label is:  1 Predcition is:  8 index is:  20280
# Label is:  7 Predcition is:  4 index is:  20309
# Label is:  5 Predcition is:  3 index is:  20312
# Label is:  7 Predcition is:  2 index is:  20376
# Label is:  4 Predcition is:  6 index is:  20411
# Label is:  8 Predcition is:  6 index is:  20440
# Label is:  7 Predcition is:  2 index is:  20480
# Label is:  3 Predcition is:  8 index is:  20556
# Label is:  6 Predcition is:  8 index is:  20583
# Label is:  3 Predcition is:  8 index is:  20592
# Label is:  4 Predcition is:  8 index is:  20609
# Label is:  7 Predcition is:  9 index is:  20644
# Label is:  1 Predcition is:  7 index is:  20665
# Label is:  7 Predcition is:  2 index is:  20692
# Label is:  7 Predcition is:  4 index is:  20717
# Label is:  7 Predcition is:  9 index is:  20748
# Label is:  3 Predcition is:  9 index is:  20801
# Label is:  1 Predcition is:  8 index is:  20982
# Label is:  3 Predcition is:  8 index is:  21188
# Label is:  3 Predcition is:  8 index is:  21254
# Label is:  0 Predcition is:  8 index is:  21308
# Label is:  1 Predcition is:  7 index is:  21376
# Label is:  7 Predcition is:  2 index is:  21430
# Label is:  6 Predcition is:  5 index is:  21473
# Label is:  4 Predcition is:  2 index is:  21474
# Label is:  7 Predcition is:  2 index is:  21499
# Label is:  6 Predcition is:  8 index is:  21517
# Label is:  7 Predcition is:  9 index is:  21535
# Label is:  5 Predcition is:  8 index is:  21539
# Label is:  1 Predcition is:  6 index is:  21578
# Label is:  2 Predcition is:  8 index is:  21591
# Label is:  3 Predcition is:  7 index is:  24327
# Label is:  4 Predcition is:  6 index is:  24404
# Label is:  1 Predcition is:  8 index is:  24431
# Label is:  5 Predcition is:  3 index is:  24453
# Label is:  7 Predcition is:  2 index is:  24480
# Label is:  6 Predcition is:  5 index is:  24552
# Label is:  9 Predcition is:  8 index is:  24554
# Label is:  1 Predcition is:  8 index is:  24618
# Label is:  2 Predcition is:  8 index is:  24669
# Label is:  7 Predcition is:  8 index is:  24769
# Label is:  0 Predcition is:  8 index is:  24789
# Label is:  3 Predcition is:  8 index is:  24817
# Label is:  8 Predcition is:  9 index is:  24840
# Label is:  1 Predcition is:  3 index is:  24971
# Label is:  6 Predcition is:  8 index is:  25004
# Label is:  4 Predcition is:  7 index is:  25048
# Label is:  2 Predcition is:  8 index is:  25068
# Label is:  5 Predcition is:  9 index is:  25135
# Label is:  7 Predcition is:  9 index is:  25164
# Label is:  7 Predcition is:  2 index is:  25206
# Label is:  7 Predcition is:  9 index is:  25215
# Label is:  6 Predcition is:  5 index is:  25255
# Label is:  1 Predcition is:  8 index is:  25258
# Label is:  1 Predcition is:  6 index is:  25260
# Label is:  4 Predcition is:  8 index is:  25278
# Label is:  9 Predcition is:  8 index is:  25425
# Label is:  1 Predcition is:  6 index is:  25527
# Label is:  7 Predcition is:  2 index is:  25559
# Label is:  4 Predcition is:  8 index is:  25571
# Label is:  9 Predcition is:  7 index is:  25656
# Label is:  7 Predcition is:  9 index is:  25837
# Label is:  7 Predcition is:  9 index is:  25912
# Label is:  6 Predcition is:  8 index is:  25939
# Label is:  3 Predcition is:  8 index is:  26123
# Label is:  7 Predcition is:  4 index is:  26134
# Label is:  6 Predcition is:  8 index is:  26137
# Label is:  4 Predcition is:  1 index is:  26164
# Label is:  0 Predcition is:  2 index is:  26170
# Label is:  6 Predcition is:  5 index is:  26179
# Label is:  7 Predcition is:  4 index is:  26292
# Label is:  4 Predcition is:  8 index is:  26317
# Label is:  1 Predcition is:  7 index is:  26350
# Label is:  5 Predcition is:  3 index is:  26354
# Label is:  7 Predcition is:  2 index is:  26380
# Label is:  2 Predcition is:  3 index is:  26395
# Label is:  5 Predcition is:  3 index is:  26419
# Label is:  5 Predcition is:  9 index is:  26429
# Label is:  4 Predcition is:  8 index is:  26482
# Label is:  7 Predcition is:  2 index is:  26563
# Label is:  6 Predcition is:  5 index is:  26569
# Label is:  6 Predcition is:  8 index is:  26571
# Label is:  1 Predcition is:  6 index is:  26641
# Label is:  5 Predcition is:  8 index is:  26698
# Label is:  5 Predcition is:  3 index is:  26720
# Label is:  0 Predcition is:  2 index is:  26764
# Label is:  7 Predcition is:  2 index is:  26774
# Label is:  1 Predcition is:  9 index is:  26883
# Label is:  5 Predcition is:  9 index is:  26908
# Label is:  1 Predcition is:  4 index is:  26912
# Label is:  0 Predcition is:  8 index is:  26935
# Label is:  1 Predcition is:  3 index is:  26941
# Label is:  7 Predcition is:  8 index is:  26949
# Label is:  7 Predcition is:  2 index is:  27000
# Label is:  9 Predcition is:  8 index is:  27051
# Label is:  7 Predcition is:  2 index is:  27052
# Label is:  7 Predcition is:  8 index is:  27078
# Label is:  7 Predcition is:  2 index is:  27089
# Label is:  7 Predcition is:  2 index is:  27257
# Label is:  3 Predcition is:  2 index is:  27274
# Label is:  5 Predcition is:  8 index is:  27318
# Label is:  0 Predcition is:  8 index is:  27336
# Label is:  7 Predcition is:  2 index is:  27372
# Label is:  3 Predcition is:  8 index is:  27453
# Label is:  8 Predcition is:  2 index is:  27472
# Label is:  3 Predcition is:  9 index is:  27511
# Label is:  4 Predcition is:  6 index is:  27512
# Label is:  9 Predcition is:  8 index is:  27542
# Label is:  3 Predcition is:  2 index is:  27549
# Label is:  7 Predcition is:  2 index is:  27557
# Label is:  9 Predcition is:  3 index is:  27569
# Label is:  7 Predcition is:  9 index is:  27651
# Label is:  4 Predcition is:  9 index is:  27665
# Label is:  7 Predcition is:  2 index is:  27676
# Label is:  1 Predcition is:  8 index is:  27716
# Label is:  7 Predcition is:  9 index is:  27799
# Label is:  7 Predcition is:  2 index is:  27930
# Label is:  7 Predcition is:  2 index is:  27951
# 711

# %%
test_predictions = test_pred_df.iloc[:, 1].to_numpy()
con_test = confusion_matrix(test_dataset.df.iloc[:,0], test_predictions)
# Confusion matrix whose i-th row and j-th column entry indicates the number of samples with 
# true label being i-th class and predicted label being j-th class.
print("\nConfusion Matrix is:\n")
print(con_test,"\n")


# Class 0 is treated as Negative
tn, fp, fn, tp = con_test.ravel()

prec_test = tp/(tp+fp)
sens = tp/(tp+fn)
spec = tn/(tn+fp)

total = tp+tn+fn+fp
acc = (tp+tn)*100/total
print("Accuracy is: %", acc)

print("\nPrecision is: ", prec_test)

print("Sensitivity is: ", sens)
print("Specificity is: ", spec)


print("\nTP: ", tp, "FP: ", fp)
print("FN: ", fn, "  TN: ", tn)
# Out:
# Confusion Matrix is:
#
# [[2735    0   17    0    0    1    6    0   25    0]
#  [   0 3081    9    8    8    4   25   10   34    2]
#  [   1    0 2701    5    0    0    2    4   16    0]
#  [   0    0   14 2764    0    3    0    7   25   12]
#  [   0    1   10    0 2747    0   10    1   16   12]
#  [   2    1    0   36    1 2411    1    0   21   13]
#  [   8    0    0    0    0   29 2701    0   29    0]
#  [   2    0  115    8   14    1    0 2871    9   39]
#  [   0    0    4    1    1    1    1    0 2592    1]
#  [   0    0    1    2   15    0    0    5   62 2686]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [103], in <cell line: 10>()
#       6 print(con_test,"\n")
#       9 # Class 0 is treated as Negative
# ---> 10 tn, fp, fn, tp = con_test.ravel()
#      12 prec_test = tp/(tp+fp)
#      13 sens = tp/(tp+fn)
#
# ValueError: too many values to unpack (expected 4)

# %%
sel2 = count2

for i in range(sel2):
    print("Image : ", i)
    print("Confidance values are : ", test_probs[test_index[i]][class1], test_probs[test_index[i]][class2], test_probs[test_index[i]][class3])
    print("Ground Truth is: ", test_df.iloc[test_index[i],0])
    print("Predicted as: ", test_predictions[test_index[i]])

dispImage(test_df, test_index[:sel2])

# %%
npv = tn/(tn+fn)
print(npv)
