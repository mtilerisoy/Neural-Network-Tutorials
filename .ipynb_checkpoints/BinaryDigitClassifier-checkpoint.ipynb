# %% [markdown]
# # Digit Classifier

# %% [markdown]
# In this playbook, you can generate and train a model that can classify between 10 different classes. These classes are the digits. If you want you can classify between any two class of digits or other multi-class classificaiton.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from torchmetrics import ConfusionMatrix

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
from torch.optim import lr_scheduler

from torch.autograd import Variable

from torch.utils.data import DataLoader, Dataset

from torchvision import transforms
from torchvision.utils import make_grid

import math
import random

from PIL import Image, ImageOps, ImageEnhance
import numbers

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Explore and Import the Data

# %% [markdown]
# Import dataframes seperatley, then merge and shuffle them

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively
_train = pd.read_csv('./train.csv')
_test = pd.read_csv('./test_labeled.csv', sep=';')

# %%
def extract_DF(df, label):
    temp = df.loc[df['label'] < label+1]
    return temp.loc[temp['label'] > label-1]

# %%
# test datasets

class1 = 6
class2 = 8
a1 = extract_DF(_train, class1)
a2 = extract_DF(_train, class2)

train_df = pd.concat([a1, a2])
train_df = train_df.sample(frac=1).reset_index(drop=True)

# train datasets
e1 = extract_DF(_test, class1)
e2 = extract_DF(_test, class2)

test_df = pd.concat([e1, e2])
test_df = test_df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# Here print the first 10 rows of these datasets to verify that they are corectly generated

# %%
print("Train:", train_df.iloc[:10,0])
print("Test:", test_df.iloc[:10,0])
# Out:
# Train: 0    6
# 1    8
# 2    6
# 3    8
# 4    8
# 5    8
# 6    6
# 7    8
# 8    6
# 9    8
# Name: label, dtype: int64
# Test: 0    6
# 1    6
# 2    8
# 3    8
# 4    6
# 5    6
# 6    8
# 7    6
# 8    6
# 9    8
# Name: label, dtype: int64

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively

n_train = len(train_df)
n_pixels = len(train_df.columns) - 1
n_class = len(set(train_df['label']))

print("Number of training samples:",n_train)
print('Number of training pixels: ', n_pixels)
print('Number of classes: ', n_class)
# Out:
# Number of training samples: 8200
# Number of training pixels:  784
# Number of classes:  2

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively

n_test = len(test_df)
n_pixels = len(test_df.columns) - 1
n_class = len(set(test_df['label']))

print("Number of training samples:",n_test)
print('Number of training pixels: ', n_pixels)
print('Number of classes: ', n_class)
# Out:
# Number of training samples: 5368
# Number of training pixels:  784
# Number of classes:  2

# %% [markdown]
# ## Display Some Images

# %%
def dispImage(df, im):
    grid = make_grid(torch.Tensor((df.iloc[im, 1:].to_numpy()/255.).reshape((-1, 28, 28))).unsqueeze(1), nrow=7)
    plt.rcParams['figure.figsize'] = (32, 150)
    plt.imshow(grid.numpy().transpose((1,2,0)))
    plt.axis('off')

# %%
random_sel = np.random.randint(n_train, size=14)
ten = range(10)

dispImage(train_df, random_sel)
print(*list(train_df.iloc[random_sel, 0].values), sep = ', ')
# Out:
# 8, 8, 6, 6, 8, 8, 8, 6, 6, 6, 8, 8, 6, 6

# %% [markdown]
# ## Distribution of the Classes among Datasets

# %%
def showHistogram(df):
    plt.rcParams['figure.figsize'] = (8, 5)
    plt.bar(df['label'].value_counts().index, df['label'].value_counts())
    plt.xticks(np.arange(10))
    plt.xlabel('Class', fontsize=16)
    plt.ylabel('Count', fontsize=16)
    plt.grid('on', axis='y')

showHistogram(train_df) # Blue si train
showHistogram(test_df) # Orange is test
print("Shape of the train_df is: ", train_df.shape)
print("Shape of the test_df is: ", test_df.shape)
# Out:
# Shape of the train_df is:  (8200, 785)
# Shape of the test_df is:  (5368, 785)

# %% [markdown]
# ## Dataloader Class Definiton

# %%
class MNIST_data(Dataset):
    """MNIST dtaa set"""
    
    
    
    def __init__(self, 
                 df_, #file_path, 
                 sep=',', 
                 isTest=False,
                 transform = transforms.Compose([transforms.ToPILImage(), transforms.ToTensor(), 
                     transforms.Normalize(mean=(0.5,), std=(0.5,))])
                ):
        
        df = df_ #pd.read_csv(file_path, sep=sep)
        self.df = df_
        
        if isTest:
            # test data
            self.X = df.iloc[:,1:].values.reshape((-1,28,28)).astype(np.uint8)[:,:,:,None]
            self.y = None
        else:
            # training data
            self.X = df.iloc[:,1:].values.reshape((-1,28,28)).astype(np.uint8)[:,:,:,None]
            self.y = torch.from_numpy(df.iloc[:,0].values)
            
        self.transform = transform
    
    def __len__(self):
        return len(self.X)
    
    def get_labels(self):
        return df.iloc[:,0]

    def __getitem__(self, idx):
        if self.y is not None:
            return self.transform(self.X[idx]), self.y[idx]
        else:
            return self.transform(self.X[idx])

# %% [markdown]
# ## Random Rotation

# %%
class RandomRotation(object):
    """
    https://github.com/pytorch/vision/tree/master/torchvision/transforms
    Rotate the image by angle.
    Args:
        degrees (sequence or float or int): Range of degrees to select from.
            If degrees is a number instead of sequence like (min, max), the range of degrees
            will be (-degrees, +degrees).
        resample ({PIL.Image.NEAREST, PIL.Image.BILINEAR, PIL.Image.BICUBIC}, optional):
            An optional resampling filter.
            See http://pillow.readthedocs.io/en/3.4.x/handbook/concepts.html#filters
            If omitted, or if the image has mode "1" or "P", it is set to PIL.Image.NEAREST.
        expand (bool, optional): Optional expansion flag.
            If true, expands the output to make it large enough to hold the entire rotated image.
            If false or omitted, make the output image the same size as the input image.
            Note that the expand flag assumes rotation around the center and no translation.
        center (2-tuple, optional): Optional center of rotation.
            Origin is the upper left corner.
            Default is the center of the image.
    """

    def __init__(self, degrees, resample=False, expand=False, center=None):
        if isinstance(degrees, numbers.Number):
            if degrees < 0:
                raise ValueError("If degrees is a single number, it must be positive.")
            self.degrees = (-degrees, degrees)
        else:
            if len(degrees) != 2:
                raise ValueError("If degrees is a sequence, it must be of len 2.")
            self.degrees = degrees

        self.resample = resample
        self.expand = expand
        self.center = center

    @staticmethod
    def get_params(degrees):
        """Get parameters for ``rotate`` for a random rotation.
        Returns:
            sequence: params to be passed to ``rotate`` for random rotation.
        """
        angle = np.random.uniform(degrees[0], degrees[1])

        return angle

    def __call__(self, img):
        """
            img (PIL Image): Image to be rotated.
        Returns:
            PIL Image: Rotated image.
        """
        
        def rotate(img, angle, resample=False, expand=False, center=None):
            """Rotate the image by angle and then (optionally) translate it by (n_columns, n_rows)
            Args:
            img (PIL Image): PIL Image to be rotated.
            angle ({float, int}): In degrees degrees counter clockwise order.
            resample ({PIL.Image.NEAREST, PIL.Image.BILINEAR, PIL.Image.BICUBIC}, optional):
            An optional resampling filter.
            See http://pillow.readthedocs.io/en/3.4.x/handbook/concepts.html#filters
            If omitted, or if the image has mode "1" or "P", it is set to PIL.Image.NEAREST.
            expand (bool, optional): Optional expansion flag.
            If true, expands the output image to make it large enough to hold the entire rotated image.
            If false or omitted, make the output image the same size as the input image.
            Note that the expand flag assumes rotation around the center and no translation.
            center (2-tuple, optional): Optional center of rotation.
            Origin is the upper left corner.
            Default is the center of the image.
            """
                
            return img.rotate(angle, resample, expand, center)

        angle = self.get_params(self.degrees)

        return rotate(img, angle, self.resample, self.expand, self.center)

# %% [markdown]
# ## Random Shift

# %%
class RandomShift(object):
    def __init__(self, shift):
        self.shift = shift
        
    @staticmethod
    def get_params(shift):
        """Get parameters for ``rotate`` for a random rotation.
        Returns:
            sequence: params to be passed to ``rotate`` for random rotation.
        """
        hshift, vshift = np.random.uniform(-shift, shift, size=2)

        return hshift, vshift 
    def __call__(self, img):
        hshift, vshift = self.get_params(self.shift)
        
        return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)

# %% [markdown]
# ## Define the Datasets and Dataloaders

# %%
batch_size = 64

train_dataset = MNIST_data(train_df, transform= transforms.Compose(
                            [transforms.ToPILImage(), RandomRotation(degrees=20), RandomShift(3),
                             transforms.ToTensor(), transforms.Normalize(mean=(0.5,), std=(0.5,))]))
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, shuffle=True)




test_dataset = MNIST_data(test_df, sep=';', isTest=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=batch_size, shuffle=False)

train_x_dataset = MNIST_data(train_df, isTest=True)
train_x_loader = torch.utils.data.DataLoader(dataset=train_x_dataset, batch_size=batch_size, shuffle=False)


test_y_dataset = MNIST_data(test_df, sep=';')
test_y_loader = torch.utils.data.DataLoader(dataset=test_y_dataset, batch_size=batch_size, shuffle=True)

# %%
dispImage(train_df, np.arange(14))
    
print(*list(train_df.iloc[:14, 0].values), sep = ', ')
print(*list(train_dataset.df.iloc[:14,0].values), sep = ', ')
# Out:
# 6, 8, 6, 8, 8, 8, 6, 8, 6, 8, 6, 6, 8, 8
# 6, 8, 6, 8, 8, 8, 6, 8, 6, 8, 6, 6, 8, 8

# %% [markdown]
# ## Demonstration of Random Rotation & Shift

# %%
rotate = RandomRotation(20)
shift = RandomShift(3)
composed = transforms.Compose([RandomRotation(20),
                               RandomShift(3)])

# Apply each of the above transforms on sample.
fig = plt.figure()
sample = transforms.ToPILImage()(train_df.iloc[65,1:].values.reshape((28,28)).astype(np.uint8)[:,:,None])
for i, tsfrm in enumerate([rotate, shift, composed]):
    transformed_sample = tsfrm(sample)

    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(tsfrm).__name__)
    ax.imshow(np.reshape(np.array(list(transformed_sample.getdata())), (-1,28)), cmap='gray')    

plt.show()
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_3660/2105636642.py:17: DeprecationWarning: AFFINE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transform.AFFINE instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_3660/2105636642.py:17: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)

# %% [markdown]
# ## Define the Neural Network

# %%
class Net(nn.Module):    
    def __init__(self):
        super(Net, self).__init__()
          
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
          
        self.classifier = nn.Sequential(
            nn.Dropout(p = 0.5),
            nn.Linear(64 * 7 * 7, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.5),
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.5),
            nn.Linear(512, 10),
        )
          
        for m in self.features.children():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        for m in self.classifier.children():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform(m.weight)
            elif isinstance(m, nn.BatchNorm1d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
                

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        
        return x

# %% [markdown]
# ## Initialize the Model

# %%
model = Net()

optimizer = optim.Adam(model.parameters(), lr=0.0001) #0.003

criterion = nn.CrossEntropyLoss()

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_3660/4122321177.py:45: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(m.weight)

# %% [markdown]
# ## Training Algorithm

# %%
loss_values = []
def train(epoch):
    model.train()

    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        
        val = F.cross_entropy(output, target, size_average=False).data
        loss_values.append(val)
        
        loss.backward()
        optimizer.step()
        
        if (batch_idx + 1)% 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, (batch_idx + 1) * len(data), len(train_loader.dataset),
                100. * (batch_idx + 1) / len(train_loader), loss.data))
    
    
    exp_lr_scheduler.step()

# %% [markdown]
# ## Evaluation of Training

# %%
def evaluate(data_loader):
    model.eval()
    loss = 0
    correct = 0
    
    for data, target in data_loader:
        data, target = Variable(data), Variable(target)
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        output = model(data)
        
        loss += F.cross_entropy(output, target, size_average=False).data

        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        
    loss /= len(data_loader.dataset)
        
    print('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.3f}%)\n'.format(
        loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))

# %% [markdown]
# ## Train the Model

# %%
n_epochs = 1

for epoch in range(n_epochs):
    train(epoch)
    evaluate(train_loader)
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_3660/2105636642.py:17: DeprecationWarning: AFFINE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transform.AFFINE instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_3660/2105636642.py:17: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /Users/ilerisoy/opt/anaconda3/envs/ml/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Train Epoch: 0 [640/8200 (8%)]	Loss: 3.156906
# Train Epoch: 0 [1280/8200 (16%)]	Loss: 2.947616
# Train Epoch: 0 [1920/8200 (23%)]	Loss: 2.218879
# Train Epoch: 0 [2560/8200 (31%)]	Loss: 2.018445
# Train Epoch: 0 [3200/8200 (39%)]	Loss: 1.645156
# Train Epoch: 0 [3840/8200 (47%)]	Loss: 1.204311
# Train Epoch: 0 [4480/8200 (54%)]	Loss: 1.176377
# Train Epoch: 0 [5120/8200 (62%)]	Loss: 1.159251
# Train Epoch: 0 [5760/8200 (70%)]	Loss: 0.717657
# Train Epoch: 0 [6400/8200 (78%)]	Loss: 0.686990
# Train Epoch: 0 [7040/8200 (85%)]	Loss: 0.752182
# Train Epoch: 0 [7680/8200 (93%)]	Loss: 0.584298
#
# Average loss: 0.3471, Accuracy: 7788/8200 (94.976%)

# %%
plt.plot(loss_values)
plt.ylabel('Loss')
plt.show()

print(loss_values[0:5], loss_values[len(loss_values)-5:])
print(len(loss_values))
# Out:
# [tensor(249.7723), tensor(237.6290), tensor(233.7677), tensor(224.3672), tensor(210.9391)] [tensor(37.2754), tensor(43.9305), tensor(23.8979), tensor(28.9652), tensor(2.8719)]
# 129

# %% [markdown]
# ## Prediction Algorithm

# %%
train_prob = []
test_prob = []
def prediciton(data_loader, df_type):
    model.eval()
    test_pred = torch.LongTensor()
    
    for i, data in enumerate(data_loader):
        data = Variable(data)
        if torch.cuda.is_available():
            data = data.cuda()
            
        output = model(data)
        
        batch_prob = F.softmax(output, dim=1)
        if df_type == "train":
            for i in range(len(batch_prob)):
                train_prob.append(batch_prob[i])
        elif df_type == "test":
            for i in range(len(batch_prob)):
                train_prob.append(batch_prob[i])
        else:
            print("Wrong df type is given...")
            return 0
        pred = output.cpu().data.max(1, keepdim=True)[1]
        test_pred = torch.cat((test_pred, pred), dim=0)
        
    return test_pred

# %%
train_pred = prediciton(train_x_loader, "train")

# %%
test_pred = prediciton(test_loader, "test")

# %% [markdown]
# ## Function to Get the Confidence Values

# %%
def getProbs(rawProbs):
    temp = []
    
    for i in range(len(rawProbs)):
        temp.append(rawProbs[i].detach().numpy())

    return temp

train_probs = getProbs(train_prob)
test_probs = getProbs(test_prob)

# %%
item = 0
print(train_probs[item][class1])
# Out:
# 0.84968865

# %% [markdown]
# # Training Prediction

# %%
train_prediction_df = pd.DataFrame(np.c_[np.arange(1, len(train_dataset)+1)[:,None], train_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# Make a numpay array by predcited labels
train_predictions = train_prediction_df.iloc[:,1].to_numpy()
train_labels = train_df.iloc[:,0].to_numpy()
print(len(train_predictions), train_predictions[:10], train_labels[:10])
# Out:
# 8200 [6 8 8 8 8 8 6 8 6 8] [6 8 6 8 8 8 6 8 6 8]

# %%
train_predictions = train_prediction_df.iloc[:, 1].to_numpy()

count = 0
train_index = []

for i in range(len(train_predictions)):
    if train_dataset.df.iloc[i,0] == train_predictions[i]:
        continue
    else:
        count +=1
        train_index.append(i)
        print("Label is: ", train_dataset.y.numpy()[i], "Predcition is: ", train_predictions[i], "index is: ", i)
print(count)
# Out:
# Label is:  6 Predcition is:  8 index is:  2
# Label is:  8 Predcition is:  6 index is:  198
# Label is:  6 Predcition is:  8 index is:  242
# Label is:  8 Predcition is:  6 index is:  249
# Label is:  6 Predcition is:  8 index is:  330
# Label is:  6 Predcition is:  8 index is:  441
# Label is:  6 Predcition is:  8 index is:  473
# Label is:  8 Predcition is:  6 index is:  517
# Label is:  8 Predcition is:  6 index is:  586
# Label is:  8 Predcition is:  6 index is:  599
# Label is:  6 Predcition is:  8 index is:  604
# Label is:  6 Predcition is:  8 index is:  772
# Label is:  6 Predcition is:  8 index is:  1052
# Label is:  6 Predcition is:  8 index is:  1150
# Label is:  8 Predcition is:  6 index is:  1188
# Label is:  8 Predcition is:  6 index is:  1377
# Label is:  6 Predcition is:  8 index is:  1521
# Label is:  8 Predcition is:  6 index is:  1844
# Label is:  6 Predcition is:  8 index is:  1907
# Label is:  6 Predcition is:  8 index is:  2048
# Label is:  6 Predcition is:  8 index is:  2087
# Label is:  6 Predcition is:  8 index is:  2133
# Label is:  6 Predcition is:  8 index is:  2243
# Label is:  6 Predcition is:  8 index is:  2259
# Label is:  6 Predcition is:  8 index is:  2276
# Label is:  8 Predcition is:  6 index is:  2338
# Label is:  6 Predcition is:  8 index is:  2435
# Label is:  6 Predcition is:  8 index is:  2530
# Label is:  6 Predcition is:  8 index is:  2564
# Label is:  6 Predcition is:  8 index is:  2592
# Label is:  6 Predcition is:  8 index is:  2692
# Label is:  6 Predcition is:  8 index is:  2820
# Label is:  6 Predcition is:  8 index is:  2942
# Label is:  8 Predcition is:  6 index is:  3004
# Label is:  8 Predcition is:  6 index is:  3027
# Label is:  6 Predcition is:  8 index is:  3042
# Label is:  8 Predcition is:  6 index is:  3083
# Label is:  8 Predcition is:  6 index is:  3110
# Label is:  8 Predcition is:  6 index is:  3256
# Label is:  6 Predcition is:  8 index is:  3321
# Label is:  6 Predcition is:  8 index is:  3334
# Label is:  6 Predcition is:  8 index is:  3369
# Label is:  6 Predcition is:  8 index is:  3475
# Label is:  8 Predcition is:  6 index is:  3487
# Label is:  6 Predcition is:  8 index is:  3548
# Label is:  6 Predcition is:  8 index is:  3790
# Label is:  8 Predcition is:  6 index is:  3811
# Label is:  8 Predcition is:  6 index is:  4156
# Label is:  6 Predcition is:  8 index is:  4215
# Label is:  6 Predcition is:  8 index is:  4221
# Label is:  8 Predcition is:  6 index is:  4293
# Label is:  8 Predcition is:  6 index is:  4518
# Label is:  8 Predcition is:  6 index is:  4833
# Label is:  6 Predcition is:  8 index is:  4836
# Label is:  8 Predcition is:  6 index is:  4871
# Label is:  8 Predcition is:  6 index is:  4882
# Label is:  6 Predcition is:  8 index is:  4990
# Label is:  8 Predcition is:  6 index is:  5207
# Label is:  6 Predcition is:  8 index is:  5215
# Label is:  8 Predcition is:  6 index is:  5216
# Label is:  6 Predcition is:  8 index is:  5241
# Label is:  6 Predcition is:  8 index is:  5302
# Label is:  6 Predcition is:  8 index is:  5341
# Label is:  6 Predcition is:  8 index is:  5497
# Label is:  6 Predcition is:  8 index is:  5700
# Label is:  8 Predcition is:  6 index is:  5787
# Label is:  8 Predcition is:  6 index is:  5795
# Label is:  8 Predcition is:  6 index is:  5824
# Label is:  8 Predcition is:  6 index is:  5887
# Label is:  6 Predcition is:  8 index is:  5892
# Label is:  6 Predcition is:  8 index is:  6052
# Label is:  6 Predcition is:  8 index is:  6232
# Label is:  8 Predcition is:  6 index is:  6250
# Label is:  6 Predcition is:  8 index is:  6308
# Label is:  6 Predcition is:  8 index is:  6321
# Label is:  8 Predcition is:  6 index is:  6446
# Label is:  8 Predcition is:  6 index is:  6558
# Label is:  8 Predcition is:  6 index is:  6568
# Label is:  8 Predcition is:  6 index is:  6597
# Label is:  6 Predcition is:  8 index is:  6610
# Label is:  6 Predcition is:  8 index is:  6623
# Label is:  8 Predcition is:  6 index is:  6889
# Label is:  6 Predcition is:  8 index is:  6892
# Label is:  8 Predcition is:  6 index is:  7015
# Label is:  6 Predcition is:  8 index is:  7030
# Label is:  8 Predcition is:  6 index is:  7037
# Label is:  8 Predcition is:  6 index is:  7109
# Label is:  8 Predcition is:  6 index is:  7175
# Label is:  6 Predcition is:  8 index is:  7249
# Label is:  6 Predcition is:  8 index is:  7365
# Label is:  6 Predcition is:  8 index is:  7447
# Label is:  8 Predcition is:  6 index is:  7529
# Label is:  6 Predcition is:  8 index is:  7673
# Label is:  8 Predcition is:  6 index is:  7703
# Label is:  6 Predcition is:  8 index is:  7824
# Label is:  8 Predcition is:  6 index is:  7908
# Label is:  6 Predcition is:  8 index is:  7941
# Label is:  8 Predcition is:  6 index is:  7970
# Label is:  6 Predcition is:  8 index is:  7992
# Label is:  8 Predcition is:  6 index is:  8117
# Label is:  6 Predcition is:  8 index is:  8119
# 101

# %%
con_train = confusion_matrix(train_dataset.df.iloc[:,0], train_predictions)
# Confusion matrix whose i-th row and j-th column entry indicates the number of samples with 
# true label being i-th class and predicted label being j-th class.
print("\nConfusion Matrix is:\n")
print(con_train,"\n")


# Class 0 is treated as Negative
tn, fp, fn, tp = con_train.ravel()

prec_test = tp/(tp+fp)
sens = tp/(tp+fn)
spec = tn/(tn+fp)

total = tp+tn+fn+fp
acc = (tp+tn)*100/total
print("Accuracy is: %", acc)

print("\nPrecision is: ", prec_test)

print("Sensitivity is: ", sens)
print("Specificity is: ", spec)


print("\nTP: ", tp, "FP: ", fp)
print("FN: ", fn, "  TN: ", tn)
# Out:
# Confusion Matrix is:
#
# [[4079   58]
#  [  43 4020]]
#
# Accuracy is: % 98.76829268292683
#
# Precision is:  0.9857773418342325
# Sensitivity is:  0.9894166871769629
# Specificity is:  0.9859801788735799
#
# TP:  4020 FP:  58
# FN:  43   TN:  4079

# %%
sel = count

for i in range(sel):
    print("Image : ", i)
    print("Confidance values are : ", train_probs[train_index[i]][class1], train_probs[train_index[i]][class2])
    print("Ground Truth is: ", train_df.iloc[train_index[i],0])
    print("Predicted as: ", train_predictions[train_index[i]])

dispImage(train_df, train_index[:sel])
# Out:
# Image :  0
# Confidance values are :  0.00950553 0.75487226
# Ground Truth is:  6
# Predicted as:  8
# Image :  1
# Confidance values are :  0.47904977 0.095301084
# Ground Truth is:  8
# Predicted as:  6
# Image :  2
# Confidance values are :  0.016673269 0.702512
# Ground Truth is:  6
# Predicted as:  8
# Image :  3
# Confidance values are :  0.4829265 0.15976322
# Ground Truth is:  8
# Predicted as:  6
# Image :  4
# Confidance values are :  0.22119857 0.2819107
# Ground Truth is:  6
# Predicted as:  8
# Image :  5
# Confidance values are :  0.10657466 0.5032837
# Ground Truth is:  6
# Predicted as:  8
# Image :  6
# Confidance values are :  0.07756447 0.49431893
# Ground Truth is:  6
# Predicted as:  8
# Image :  7
# Confidance values are :  0.504491 0.13730481
# Ground Truth is:  8
# Predicted as:  6
# Image :  8
# Confidance values are :  0.27042282 0.21901359
# Ground Truth is:  8
# Predicted as:  6
# Image :  9
# Confidance values are :  0.38112637 0.24546485
# Ground Truth is:  8
# Predicted as:  6
# Image :  10
# Confidance values are :  0.049159992 0.6099998
# Ground Truth is:  6
# Predicted as:  8
# Image :  11
# Confidance values are :  0.22847182 0.25505695
# Ground Truth is:  6
# Predicted as:  8
# Image :  12
# Confidance values are :  0.0065878723 0.8088706
# Ground Truth is:  6
# Predicted as:  8
# Image :  13
# Confidance values are :  0.22623442 0.30922177
# Ground Truth is:  6
# Predicted as:  8
# Image :  14
# Confidance values are :  0.24196865 0.22579405
# Ground Truth is:  8
# Predicted as:  6
# Image :  15
# Confidance values are :  0.5757295 0.06312887
# Ground Truth is:  8
# Predicted as:  6
# Image :  16
# Confidance values are :  0.019047812 0.74433595
# Ground Truth is:  6
# Predicted as:  8
# Image :  17
# Confidance values are :  0.3096948 0.22620907
# Ground Truth is:  8
# Predicted as:  6
# Image :  18
# Confidance values are :  0.23470673 0.33654776
# Ground Truth is:  6
# Predicted as:  8
# Image :  19
# Confidance values are :  0.028767673 0.6679241
# Ground Truth is:  6
# Predicted as:  8
# Image :  20
# Confidance values are :  0.28396916 0.29145083
# Ground Truth is:  6
# Predicted as:  8
# Image :  21
# Confidance values are :  0.029290233 0.71978027
# Ground Truth is:  6
# Predicted as:  8
# Image :  22
# Confidance values are :  0.20612955 0.40984768
# Ground Truth is:  6
# Predicted as:  8
# Image :  23
# Confidance values are :  0.1831314 0.34304708
# Ground Truth is:  6
# Predicted as:  8
# Image :  24
# Confidance values are :  0.123704396 0.42929697
# Ground Truth is:  6
# Predicted as:  8
# Image :  25
# Confidance values are :  0.29815152 0.27821252
# Ground Truth is:  8
# Predicted as:  6
# Image :  26
# Confidance values are :  0.25008973 0.27453533
# Ground Truth is:  6
# Predicted as:  8
# Image :  27
# Confidance values are :  0.11366625 0.3393152
# Ground Truth is:  6
# Predicted as:  8
# Image :  28
# Confidance values are :  0.26198402 0.3527939
# Ground Truth is:  6
# Predicted as:  8
# Image :  29
# Confidance values are :  0.15461046 0.40094766
# Ground Truth is:  6
# Predicted as:  8
# Image :  30
# Confidance values are :  0.020652091 0.7080261
# Ground Truth is:  6
# Predicted as:  8
# Image :  31
# Confidance values are :  0.21406558 0.32887653
# Ground Truth is:  6
# Predicted as:  8
# Image :  32
# Confidance values are :  0.19047208 0.36834115
# Ground Truth is:  6
# Predicted as:  8
# Image :  33
# Confidance values are :  0.47441435 0.05347634
# Ground Truth is:  8
# Predicted as:  6
# Image :  34
# Confidance values are :  0.58805776 0.08618567
# Ground Truth is:  8
# Predicted as:  6
# Image :  35
# Confidance values are :  0.08445757 0.4344809
# Ground Truth is:  6
# Predicted as:  8
# Image :  36
# Confidance values are :  0.38018584 0.07956365
# Ground Truth is:  8
# Predicted as:  6
# Image :  37
# Confidance values are :  0.24793476 0.24663098
# Ground Truth is:  8
# Predicted as:  6
# Image :  38
# Confidance values are :  0.28077972 0.16598357
# Ground Truth is:  8
# Predicted as:  6
# Image :  39
# Confidance values are :  0.102849066 0.5441412
# Ground Truth is:  6
# Predicted as:  8
# Image :  40
# Confidance values are :  0.044174112 0.58309025
# Ground Truth is:  6
# Predicted as:  8
# Image :  41
# Confidance values are :  0.26269317 0.26770616
# Ground Truth is:  6
# Predicted as:  8
# Image :  42
# Confidance values are :  0.12406987 0.4534293
# Ground Truth is:  6
# Predicted as:  8
# Image :  43
# Confidance values are :  0.53069544 0.13628598
# Ground Truth is:  8
# Predicted as:  6
# Image :  44
# Confidance values are :  0.21765503 0.33376774
# Ground Truth is:  6
# Predicted as:  8
# Image :  45
# Confidance values are :  0.045222063 0.5364336
# Ground Truth is:  6
# Predicted as:  8
# Image :  46
# Confidance values are :  0.31075346 0.2812733
# Ground Truth is:  8
# Predicted as:  6
# Image :  47
# Confidance values are :  0.321759 0.2517882
# Ground Truth is:  8
# Predicted as:  6
# Image :  48
# Confidance values are :  0.09017607 0.47763255
# Ground Truth is:  6
# Predicted as:  8
# Image :  49
# Confidance values are :  0.16006282 0.28261763
# Ground Truth is:  6
# Predicted as:  8
# Image :  50
# Confidance values are :  0.54630846 0.06488882
# Ground Truth is:  8
# Predicted as:  6
# Image :  51
# Confidance values are :  0.29574525 0.25047976
# Ground Truth is:  8
# Predicted as:  6
# Image :  52
# Confidance values are :  0.41007912 0.16490287
# Ground Truth is:  8
# Predicted as:  6
# Image :  53
# Confidance values are :  0.22215196 0.2510616
# Ground Truth is:  6
# Predicted as:  8
# Image :  54
# Confidance values are :  0.54015124 0.08724637
# Ground Truth is:  8
# Predicted as:  6
# Image :  55
# Confidance values are :  0.7171906 0.043655314
# Ground Truth is:  8
# Predicted as:  6
# Image :  56
# Confidance values are :  0.21006298 0.24982724
# Ground Truth is:  6
# Predicted as:  8
# Image :  57
# Confidance values are :  0.4605574 0.16870308
# Ground Truth is:  8
# Predicted as:  6
# Image :  58
# Confidance values are :  0.053422403 0.6060498
# Ground Truth is:  6
# Predicted as:  8
# Image :  59
# Confidance values are :  0.36683667 0.17528611
# Ground Truth is:  8
# Predicted as:  6
# Image :  60
# Confidance values are :  0.20390965 0.26924488
# Ground Truth is:  6
# Predicted as:  8
# Image :  61
# Confidance values are :  0.09475653 0.4403055
# Ground Truth is:  6
# Predicted as:  8
# Image :  62
# Confidance values are :  0.22550291 0.29453143
# Ground Truth is:  6
# Predicted as:  8
# Image :  63
# Confidance values are :  0.14687748 0.25098562
# Ground Truth is:  6
# Predicted as:  8
# Image :  64
# Confidance values are :  0.23590158 0.2949238
# Ground Truth is:  6
# Predicted as:  8
# Image :  65
# Confidance values are :  0.3740084 0.20099889
# Ground Truth is:  8
# Predicted as:  6
# Image :  66
# Confidance values are :  0.28095856 0.16936286
# Ground Truth is:  8
# Predicted as:  6
# Image :  67
# Confidance values are :  0.31710035 0.30529973
# Ground Truth is:  8
# Predicted as:  6
# Image :  68
# Confidance values are :  0.22753644 0.19966696
# Ground Truth is:  8
# Predicted as:  6
# Image :  69
# Confidance values are :  0.13873011 0.3586868
# Ground Truth is:  6
# Predicted as:  8
# Image :  70
# Confidance values are :  0.23151754 0.2468301
# Ground Truth is:  6
# Predicted as:  8
# Image :  71
# Confidance values are :  0.16005808 0.31645885
# Ground Truth is:  6
# Predicted as:  8
# Image :  72
# Confidance values are :  0.5439967 0.06960898
# Ground Truth is:  8
# Predicted as:  6
# Image :  73
# Confidance values are :  0.23059446 0.24441832
# Ground Truth is:  6
# Predicted as:  8
# Image :  74
# Confidance values are :  0.0428971 0.5485587
# Ground Truth is:  6
# Predicted as:  8
# Image :  75
# Confidance values are :  0.6655198 0.041346457
# Ground Truth is:  8
# Predicted as:  6
# Image :  76
# Confidance values are :  0.5604567 0.0914241
# Ground Truth is:  8
# Predicted as:  6
# Image :  77
# Confidance values are :  0.49554145 0.12668055
# Ground Truth is:  8
# Predicted as:  6
# Image :  78
# Confidance values are :  0.524532 0.06925255
# Ground Truth is:  8
# Predicted as:  6
# Image :  79
# Confidance values are :  0.1496132 0.25404036
# Ground Truth is:  6
# Predicted as:  8
# Image :  80
# Confidance values are :  0.26937702 0.2825342
# Ground Truth is:  6
# Predicted as:  8
# Image :  81
# Confidance values are :  0.3403665 0.16280453
# Ground Truth is:  8
# Predicted as:  6
# Image :  82
# Confidance values are :  0.004774089 0.8556287
# Ground Truth is:  6
# Predicted as:  8
# Image :  83
# Confidance values are :  0.24150231 0.15930888
# Ground Truth is:  8
# Predicted as:  6
# Image :  84
# Confidance values are :  0.2125398 0.28256446
# Ground Truth is:  6
# Predicted as:  8
# Image :  85
# Confidance values are :  0.6406733 0.085775204
# Ground Truth is:  8
# Predicted as:  6
# Image :  86
# Confidance values are :  0.49806908 0.16786985
# Ground Truth is:  8
# Predicted as:  6
# Image :  87
# Confidance values are :  0.74165916 0.02360215
# Ground Truth is:  8
# Predicted as:  6
# Image :  88
# Confidance values are :  0.22056417 0.24139309
# Ground Truth is:  6
# Predicted as:  8
# Image :  89
# Confidance values are :  0.06907266 0.47526598
# Ground Truth is:  6
# Predicted as:  8
# Image :  90
# Confidance values are :  0.040784672 0.6171723
# Ground Truth is:  6
# Predicted as:  8
# Image :  91
# Confidance values are :  0.5712614 0.05454578
# Ground Truth is:  8
# Predicted as:  6
# Image :  92
# Confidance values are :  0.1342618 0.37430528
# Ground Truth is:  6
# Predicted as:  8
# Image :  93
# Confidance values are :  0.48694956 0.13175486
# Ground Truth is:  8
# Predicted as:  6
# Image :  94
# Confidance values are :  0.05203852 0.5326161
# Ground Truth is:  6
# Predicted as:  8
# Image :  95
# Confidance values are :  0.48134217 0.108907335
# Ground Truth is:  8
# Predicted as:  6
# Image :  96
# Confidance values are :  0.05105129 0.52766216
# Ground Truth is:  6
# Predicted as:  8
# Image :  97
# Confidance values are :  0.6222489 0.058333274
# Ground Truth is:  8
# Predicted as:  6
# Image :  98
# Confidance values are :  0.12245618 0.3423947
# Ground Truth is:  6
# Predicted as:  8
# Image :  99
# Confidance values are :  0.29139152 0.2558441
# Ground Truth is:  8
# Predicted as:  6
# Image :  100
# Confidance values are :  0.0045271576 0.8499057
# Ground Truth is:  6
# Predicted as:  8

# %% [markdown]
# # Test Prediction

# %%
test_pred_df = pd.DataFrame(np.c_[np.arange(1, len(test_dataset)+1)[:,None], test_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# %%
test_prediction_df = pd.DataFrame(np.c_[np.arange(1, len(test_dataset)+1)[:,None], test_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# Make a numpay array by predcited labels
test_predictions = test_prediction_df.iloc[:,1].to_numpy()
test_labels = test_df.iloc[:,0].to_numpy()
print(len(test_predictions), test_predictions[:10], test_labels[:10])

# %%
test_predictions = test_prediction_df.iloc[:, 1].to_numpy()

count2 = 0
test_index = []

for i in range(len(test_predictions)):
    if test_dataset.df.iloc[i,0] == test_predictions[i]:
        continue
    else:
        count2 +=1
        test_index.append(i)
        print("Label is: ", test_dataset.y.numpy()[i], "Predcition is: ", test_predictions[i], "index is: ", i)
print(count2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 test_predictions = test_prediction_df.iloc[:, 1].to_numpy()
#       3 count2 = 0
#       4 test_index = []
#
# NameError: name 'test_prediction_df' is not defined

# %%
sel = 



for i in range(sel):

    print("Confidance values are : ", test_probs[test_index[i]][class1], test_probs[train_index[i]][class2])
    print("Ground Truth is: ", test_df.iloc[test_index[i],0])
    print("Predicted as: ", test_predictions[test_index[i]])

dispImage(test_df, test_index[:sel])
# Out:
#   Input In [35]
#     sel =
#           ^
# SyntaxError: invalid syntax

# %%
test_predictions = test_pred_df.iloc[:, 1].to_numpy()
con_test = confusion_matrix(test_dataset.df.iloc[:,0], test_predictions)
# Confusion matrix whose i-th row and j-th column entry indicates the number of samples with 
# true label being i-th class and predicted label being j-th class.
print("\nConfusion Matrix is:\n")
print(con_test,"\n")


# Class 0 is treated as Negative
tn, fp, fn, tp = con_test.ravel()

prec_test = tp/(tp+fp)
sens = tp/(tp+fn)
spec = tn/(tn+fp)

total = tp+tn+fn+fp
acc = (tp+tn)*100/total
print("Accuracy is: %", acc)

print("\nPrecision is: ", prec_test)

print("Sensitivity is: ", sens)
print("Specificity is: ", spec)


print("\nTP: ", tp, "FP: ", fp)
print("FN: ", fn, "  TN: ", tn)
# Out:
# Confusion Matrix is:
#
# [[2767    0]
#  [2587   14]]
#
# Accuracy is: % 51.8070044709389
#
# Precision is:  1.0
# Sensitivity is:  0.005382545174932718
# Specificity is:  1.0
#
# TP:  14 FP:  0
# FN:  2587   TN:  2767

# %%
npv = tn/(tn+fn)
print(npv)
# Out:
# 0.5168098617855809
