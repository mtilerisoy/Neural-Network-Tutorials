# %% [markdown]
# # Digit Classifier

# %% [markdown]
# In this playbook, you can generate and train a model that can classify between 10 different classes. These classes are the digits. If you want you can classify between any two class of digits or other multi-class classificaiton.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from torchmetrics import ConfusionMatrix

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
from torch.optim import lr_scheduler

from torch.autograd import Variable

from torch.utils.data import DataLoader, Dataset

from torchvision import transforms
from torchvision.utils import make_grid

import math
import random

from PIL import Image, ImageOps, ImageEnhance
import numbers

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Explore and Import the Data

# %% [markdown]
# Import dataframes seperatley, then merge and shuffle them

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively
_train = pd.read_csv('./train.csv')
_test = pd.read_csv('./test_labeled.csv', sep=';')

# %%
def extract_DF(df, label):
    temp = df.loc[df['label'] < label+1]
    return temp.loc[temp['label'] > label-1]

# %%
# test datasets

class1 = 6
class2 = 8
a1 = extract_DF(_train, class1)
a2 = extract_DF(_train, class2)

train_df = pd.concat([a1, a2])
train_df = train_df.sample(frac=1).reset_index(drop=True)

# train datasets
e1 = extract_DF(_test, class1)
e2 = extract_DF(_test, class2)

test_df = pd.concat([e1, e2])
test_df = test_df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# Here print the first 10 rows of these datasets to verify that they are corectly generated

# %%
print("Train:", train_df.iloc[:10,0])
print("Test:", test_df.iloc[:10,0])
# Out:
# Train: 0    8
# 1    6
# 2    6
# 3    8
# 4    6
# 5    6
# 6    6
# 7    8
# 8    8
# 9    6
# Name: label, dtype: int64
# Test: 0    8
# 1    6
# 2    8
# 3    8
# 4    8
# 5    8
# 6    6
# 7    8
# 8    6
# 9    6
# Name: label, dtype: int64

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively

n_train = len(train_df)
n_pixels = len(train_df.columns) - 1
n_class = len(set(train_df['label']))

print("Number of training samples:",n_train)
print('Number of training pixels: ', n_pixels)
print('Number of classes: ', n_class)
# Out:
# Number of training samples: 8200
# Number of training pixels:  784
# Number of classes:  2

# %%
# 28x28 pixels image, has first 2 columns as ImageId and label respectively

n_test = len(test_df)
n_pixels = len(test_df.columns) - 1
n_class = len(set(test_df['label']))

print("Number of training samples:",n_test)
print('Number of training pixels: ', n_pixels)
print('Number of classes: ', n_class)
# Out:
# Number of training samples: 5368
# Number of training pixels:  784
# Number of classes:  2

# %% [markdown]
# ## Display Some Images

# %%
def dispImage(df, im):
    grid = make_grid(torch.Tensor((df.iloc[im, 1:].to_numpy()/255.).reshape((-1, 28, 28))).unsqueeze(1), nrow=7)
    plt.rcParams['figure.figsize'] = (32, 150)
    plt.imshow(grid.numpy().transpose((1,2,0)))
    plt.axis('off')

# %%
random_sel = np.random.randint(n_train, size=14)
ten = range(10)

dispImage(train_df, random_sel)
print(*list(train_df.iloc[random_sel, 0].values), sep = ', ')
# Out:
# 8, 6, 6, 8, 8, 8, 8, 8, 8, 8, 6, 6, 8, 6

# %% [markdown]
# ## Distribution of the Classes among Datasets

# %%
def showHistogram(df):
    plt.rcParams['figure.figsize'] = (8, 5)
    plt.bar(df['label'].value_counts().index, df['label'].value_counts())
    plt.xticks(np.arange(10))
    plt.xlabel('Class', fontsize=16)
    plt.ylabel('Count', fontsize=16)
    plt.grid('on', axis='y')

showHistogram(train_df) # Blue si train
showHistogram(test_df) # Orange is test
print("Shape of the train_df is: ", train_df.shape)
print("Shape of the test_df is: ", test_df.shape)
# Out:
# Shape of the train_df is:  (8200, 785)
# Shape of the test_df is:  (5368, 785)

# %% [markdown]
# ## Dataloader Class Definiton

# %%
class MNIST_data(Dataset):
    """MNIST dtaa set"""
    
    
    
    def __init__(self, 
                 df_, #file_path, 
                 sep=',', 
                 isTest=False,
                 transform = transforms.Compose([transforms.ToPILImage(), transforms.ToTensor(), 
                     transforms.Normalize(mean=(0.5,), std=(0.5,))])
                ):
        
        df = df_ #pd.read_csv(file_path, sep=sep)
        self.df = df_
        
        if isTest:
            # test data
            self.X = df.iloc[:,1:].values.reshape((-1,28,28)).astype(np.uint8)[:,:,:,None]
            self.y = None
        else:
            # training data
            self.X = df.iloc[:,1:].values.reshape((-1,28,28)).astype(np.uint8)[:,:,:,None]
            self.y = torch.from_numpy(df.iloc[:,0].values)
            
        self.transform = transform
    
    def __len__(self):
        return len(self.X)
    
    def get_labels(self):
        return df.iloc[:,0]

    def __getitem__(self, idx):
        if self.y is not None:
            return self.transform(self.X[idx]), self.y[idx]
        else:
            return self.transform(self.X[idx])

# %% [markdown]
# ## Random Rotation

# %%
class RandomRotation(object):
    """
    https://github.com/pytorch/vision/tree/master/torchvision/transforms
    Rotate the image by angle.
    Args:
        degrees (sequence or float or int): Range of degrees to select from.
            If degrees is a number instead of sequence like (min, max), the range of degrees
            will be (-degrees, +degrees).
        resample ({PIL.Image.NEAREST, PIL.Image.BILINEAR, PIL.Image.BICUBIC}, optional):
            An optional resampling filter.
            See http://pillow.readthedocs.io/en/3.4.x/handbook/concepts.html#filters
            If omitted, or if the image has mode "1" or "P", it is set to PIL.Image.NEAREST.
        expand (bool, optional): Optional expansion flag.
            If true, expands the output to make it large enough to hold the entire rotated image.
            If false or omitted, make the output image the same size as the input image.
            Note that the expand flag assumes rotation around the center and no translation.
        center (2-tuple, optional): Optional center of rotation.
            Origin is the upper left corner.
            Default is the center of the image.
    """

    def __init__(self, degrees, resample=False, expand=False, center=None):
        if isinstance(degrees, numbers.Number):
            if degrees < 0:
                raise ValueError("If degrees is a single number, it must be positive.")
            self.degrees = (-degrees, degrees)
        else:
            if len(degrees) != 2:
                raise ValueError("If degrees is a sequence, it must be of len 2.")
            self.degrees = degrees

        self.resample = resample
        self.expand = expand
        self.center = center

    @staticmethod
    def get_params(degrees):
        """Get parameters for ``rotate`` for a random rotation.
        Returns:
            sequence: params to be passed to ``rotate`` for random rotation.
        """
        angle = np.random.uniform(degrees[0], degrees[1])

        return angle

    def __call__(self, img):
        """
            img (PIL Image): Image to be rotated.
        Returns:
            PIL Image: Rotated image.
        """
        
        def rotate(img, angle, resample=False, expand=False, center=None):
            """Rotate the image by angle and then (optionally) translate it by (n_columns, n_rows)
            Args:
            img (PIL Image): PIL Image to be rotated.
            angle ({float, int}): In degrees degrees counter clockwise order.
            resample ({PIL.Image.NEAREST, PIL.Image.BILINEAR, PIL.Image.BICUBIC}, optional):
            An optional resampling filter.
            See http://pillow.readthedocs.io/en/3.4.x/handbook/concepts.html#filters
            If omitted, or if the image has mode "1" or "P", it is set to PIL.Image.NEAREST.
            expand (bool, optional): Optional expansion flag.
            If true, expands the output image to make it large enough to hold the entire rotated image.
            If false or omitted, make the output image the same size as the input image.
            Note that the expand flag assumes rotation around the center and no translation.
            center (2-tuple, optional): Optional center of rotation.
            Origin is the upper left corner.
            Default is the center of the image.
            """
                
            return img.rotate(angle, resample, expand, center)

        angle = self.get_params(self.degrees)

        return rotate(img, angle, self.resample, self.expand, self.center)

# %% [markdown]
# ## Random Shift

# %%
class RandomShift(object):
    def __init__(self, shift):
        self.shift = shift
        
    @staticmethod
    def get_params(shift):
        """Get parameters for ``rotate`` for a random rotation.
        Returns:
            sequence: params to be passed to ``rotate`` for random rotation.
        """
        hshift, vshift = np.random.uniform(-shift, shift, size=2)

        return hshift, vshift 
    def __call__(self, img):
        hshift, vshift = self.get_params(self.shift)
        
        return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)

# %% [markdown]
# ## Define the Datasets and Dataloaders

# %%
batch_size = 640

train_dataset = MNIST_data(train_df, transform= transforms.Compose(
                            [transforms.ToPILImage(), RandomRotation(degrees=20), RandomShift(3),
                             transforms.ToTensor(), transforms.Normalize(mean=(0.5,), std=(0.5,))]))
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, shuffle=True)




test_dataset = MNIST_data(test_df, sep=';', isTest=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=batch_size, shuffle=False)

train_x_dataset = MNIST_data(train_df, isTest=True)
train_x_loader = torch.utils.data.DataLoader(dataset=train_x_dataset, batch_size=batch_size, shuffle=False)


test_y_dataset = MNIST_data(test_df, sep=';')
test_y_loader = torch.utils.data.DataLoader(dataset=test_y_dataset, batch_size=batch_size, shuffle=True)

# %%
dispImage(train_df, np.arange(14))
    
print(*list(train_df.iloc[:14, 0].values), sep = ', ')
print(*list(train_dataset.df.iloc[:14,0].values), sep = ', ')
# Out:
# 8, 6, 6, 8, 6, 6, 6, 8, 8, 6, 6, 6, 8, 6
# 8, 6, 6, 8, 6, 6, 6, 8, 8, 6, 6, 6, 8, 6

# %% [markdown]
# ## Demonstration of Random Rotation & Shift

# %%
rotate = RandomRotation(20)
shift = RandomShift(3)
composed = transforms.Compose([RandomRotation(20),
                               RandomShift(3)])

# Apply each of the above transforms on sample.
fig = plt.figure()
sample = transforms.ToPILImage()(train_df.iloc[65,1:].values.reshape((28,28)).astype(np.uint8)[:,:,None])
for i, tsfrm in enumerate([rotate, shift, composed]):
    transformed_sample = tsfrm(sample)

    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(tsfrm).__name__)
    ax.imshow(np.reshape(np.array(list(transformed_sample.getdata())), (-1,28)), cmap='gray')    

plt.show()
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_24398/2105636642.py:17: DeprecationWarning: AFFINE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transform.AFFINE instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_24398/2105636642.py:17: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)

# %% [markdown]
# ## Define the Neural Network

# %%
class Net(nn.Module):    
    def __init__(self):
        super(Net, self).__init__()
          
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
          
        self.classifier = nn.Sequential(
            nn.Dropout(p = 0.5),
            nn.Linear(64 * 7 * 7, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.5),
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.5),
            nn.Linear(512, 10),
        )
          
        for m in self.features.children():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        for m in self.classifier.children():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform(m.weight)
            elif isinstance(m, nn.BatchNorm1d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
                

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        
        return x

# %% [markdown]
# ## Initialize the Model

# %%
model = Net()

optimizer = optim.Adam(model.parameters(), lr=0.001) #0.003

criterion = nn.CrossEntropyLoss()

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=4, gamma=0.1)

if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_24398/4122321177.py:45: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(m.weight)

# %% [markdown]
# ## Training Algorithm

# %%
loss_values = []
def train(epoch):
    model.train()

    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        
        val = F.cross_entropy(output, target, size_average=False).data
        loss_values.append(val)
        
        loss.backward()
        optimizer.step()
        
        if (batch_idx + 1)% 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, (batch_idx + 1) * len(data), len(train_loader.dataset),
                100. * (batch_idx + 1) / len(train_loader), loss.data))
    
    
    exp_lr_scheduler.step()

# %% [markdown]
# ## Evaluation of Training

# %%
def evaluate(data_loader):
    model.eval()
    loss = 0
    correct = 0
    
    for data, target in data_loader:
        data, target = Variable(data), Variable(target)
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        output = model(data)
        
        loss += F.cross_entropy(output, target, size_average=False).data

        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        
    loss /= len(data_loader.dataset)
        
    print('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.3f}%)\n'.format(
        loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))

# %% [markdown]
# ## Train the Model

# %%
n_epochs = 26

for epoch in range(n_epochs):
    train(epoch)
    evaluate(train_loader)
# Out:
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_24398/2105636642.py:17: DeprecationWarning: AFFINE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transform.AFFINE instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /var/folders/h2/0yz4qqt96pl7pfv1jmlkqfp40000gn/T/ipykernel_24398/2105636642.py:17: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   return img.transform(img.size, Image.AFFINE, (1,0,hshift,0,1,vshift), resample=Image.BICUBIC, fill=1)
# /Users/ilerisoy/opt/anaconda3/envs/ml/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Train Epoch: 0 [6400/8200 (77%)]	Loss: 0.287969
#
# Average loss: 2.4469, Accuracy: 4137/8200 (50.451%)
#
# Train Epoch: 1 [6400/8200 (77%)]	Loss: 0.113767
#
# Average loss: 1.4742, Accuracy: 4905/8200 (59.817%)
#
# Train Epoch: 2 [6400/8200 (77%)]	Loss: 0.036403
#
# Average loss: 0.4113, Accuracy: 7154/8200 (87.244%)
#
# Train Epoch: 3 [6400/8200 (77%)]	Loss: 0.040366
#
# Average loss: 0.0610, Accuracy: 8048/8200 (98.146%)
#
# Train Epoch: 4 [6400/8200 (77%)]	Loss: 0.072964
#
# Average loss: 0.0311, Accuracy: 8117/8200 (98.988%)
#
# Train Epoch: 5 [6400/8200 (77%)]	Loss: 0.058038
#
# Average loss: 0.0288, Accuracy: 8131/8200 (99.159%)
#
# Train Epoch: 6 [6400/8200 (77%)]	Loss: 0.026318
#
# Average loss: 0.0219, Accuracy: 8145/8200 (99.329%)
#
# Train Epoch: 7 [6400/8200 (77%)]	Loss: 0.033566
#
# Average loss: 0.0199, Accuracy: 8147/8200 (99.354%)
#
# Train Epoch: 8 [6400/8200 (77%)]	Loss: 0.019455
#
# Average loss: 0.0232, Accuracy: 8139/8200 (99.256%)
#
# Train Epoch: 9 [6400/8200 (77%)]	Loss: 0.045540
#
# Average loss: 0.0202, Accuracy: 8146/8200 (99.341%)
#
# Train Epoch: 10 [6400/8200 (77%)]	Loss: 0.027439
#
# Average loss: 0.0215, Accuracy: 8147/8200 (99.354%)
#
# Train Epoch: 11 [6400/8200 (77%)]	Loss: 0.028020
#
# Average loss: 0.0206, Accuracy: 8152/8200 (99.415%)
#
# Train Epoch: 12 [6400/8200 (77%)]	Loss: 0.041209
#
# Average loss: 0.0204, Accuracy: 8152/8200 (99.415%)
#
# Train Epoch: 13 [6400/8200 (77%)]	Loss: 0.025764
#
# Average loss: 0.0232, Accuracy: 8133/8200 (99.183%)
#
# Train Epoch: 14 [6400/8200 (77%)]	Loss: 0.041407
#
# Average loss: 0.0223, Accuracy: 8146/8200 (99.341%)
#
# Train Epoch: 15 [6400/8200 (77%)]	Loss: 0.029944
#
# Average loss: 0.0215, Accuracy: 8144/8200 (99.317%)
#
# Train Epoch: 16 [6400/8200 (77%)]	Loss: 0.024156
#
# Average loss: 0.0198, Accuracy: 8150/8200 (99.390%)
#
# Train Epoch: 17 [6400/8200 (77%)]	Loss: 0.044628
#
# Average loss: 0.0215, Accuracy: 8146/8200 (99.341%)
#
# Train Epoch: 18 [6400/8200 (77%)]	Loss: 0.039114
#
# Average loss: 0.0202, Accuracy: 8147/8200 (99.354%)
#
# Train Epoch: 19 [6400/8200 (77%)]	Loss: 0.048466
#
# Average loss: 0.0192, Accuracy: 8158/8200 (99.488%)
#
# Train Epoch: 20 [6400/8200 (77%)]	Loss: 0.018257
#
# Average loss: 0.0229, Accuracy: 8140/8200 (99.268%)
#
# Train Epoch: 21 [6400/8200 (77%)]	Loss: 0.045948
#
# Average loss: 0.0220, Accuracy: 8136/8200 (99.220%)
#
# Train Epoch: 22 [6400/8200 (77%)]	Loss: 0.018445
#
# Average loss: 0.0220, Accuracy: 8145/8200 (99.329%)
#
# Train Epoch: 23 [6400/8200 (77%)]	Loss: 0.042107
#
# Average loss: 0.0194, Accuracy: 8150/8200 (99.390%)
#
# Train Epoch: 24 [6400/8200 (77%)]	Loss: 0.032868
#
# Average loss: 0.0217, Accuracy: 8139/8200 (99.256%)
#
# Train Epoch: 25 [6400/8200 (77%)]	Loss: 0.031184
#
# Average loss: 0.0245, Accuracy: 8135/8200 (99.207%)

# %%
plt.plot(loss_values)
plt.ylabel('Loss')
plt.show()

print(loss_values[0:5], loss_values[len(loss_values)-5:])
print(len(loss_values))
# Out:
# [tensor(1852.8032), tensor(1380.6384), tensor(1009.2878), tensor(751.8617), tensor(568.6559)] [tensor(22.2696), tensor(19.9578), tensor(32.0043), tensor(15.8630), tensor(26.7719)]
# 338

# %% [markdown]
# ## Prediction Algorithm

# %%
train_prob = []
test_prob = []
def prediciton(data_loader, df_type):
    model.eval()
    test_pred = torch.LongTensor()
    
    for i, data in enumerate(data_loader):
        data = Variable(data)
        if torch.cuda.is_available():
            data = data.cuda()
            
        output = model(data)
        
        batch_prob = F.softmax(output, dim=1)
        if df_type == "train":
            for i in range(len(batch_prob)):
                train_prob.append(batch_prob[i])
        elif df_type == "test":
            for i in range(len(batch_prob)):
                test_prob.append(batch_prob[i])
        else:
            print("Wrong df type is given...")
            return 0
        pred = output.cpu().data.max(1, keepdim=True)[1]
        test_pred = torch.cat((test_pred, pred), dim=0)
        
    return test_pred

# %%
train_pred = prediciton(train_x_loader, "train")

# %%
test_pred = prediciton(test_loader, "test")

# %% [markdown]
# ## Function to Get the Confidence Values

# %%
def getProbs(rawProbs):
    temp = []
    
    for i in range(len(rawProbs)):
        temp.append(rawProbs[i].detach().numpy())

    return temp

train_probs = getProbs(train_prob)
test_probs = getProbs(test_prob)

# %%
item = 0
print(train_probs[item][class1])
print(test_probs[item][class1])
# Out:
# 2.849535e-05
# 8.867808e-07

# %% [markdown]
# # Training Prediction

# %%
train_prediction_df = pd.DataFrame(np.c_[np.arange(1, len(train_dataset)+1)[:,None], train_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# Make a numpay array by predcited labels
train_predictions = train_prediction_df.iloc[:,1].to_numpy()
train_labels = train_df.iloc[:,0].to_numpy()
print(len(train_predictions), train_predictions[:10], train_labels[:10])
# Out:
# 8200 [8 6 6 8 6 6 6 8 8 6] [8 6 6 8 6 6 6 8 8 6]

# %%
train_predictions = train_prediction_df.iloc[:, 1].to_numpy()

count = 0
train_index = []

for i in range(len(train_predictions)):
    if train_dataset.df.iloc[i,0] == train_predictions[i]:
        continue
    else:
        count +=1
        train_index.append(i)
        print("Label is: ", train_dataset.y.numpy()[i], "Predcition is: ", train_predictions[i], "index is: ", i)
print(count)
# Out:
# Label is:  8 Predcition is:  6 index is:  456
# Label is:  8 Predcition is:  6 index is:  636
# Label is:  6 Predcition is:  8 index is:  834
# Label is:  8 Predcition is:  6 index is:  1843
# Label is:  8 Predcition is:  6 index is:  2066
# Label is:  8 Predcition is:  6 index is:  2192
# Label is:  6 Predcition is:  8 index is:  2684
# Label is:  8 Predcition is:  6 index is:  2904
# Label is:  8 Predcition is:  6 index is:  3201
# Label is:  8 Predcition is:  6 index is:  3253
# Label is:  6 Predcition is:  8 index is:  3764
# Label is:  8 Predcition is:  6 index is:  3874
# Label is:  8 Predcition is:  6 index is:  4562
# Label is:  8 Predcition is:  6 index is:  5077
# Label is:  6 Predcition is:  8 index is:  5334
# Label is:  8 Predcition is:  6 index is:  5386
# Label is:  8 Predcition is:  6 index is:  6273
# Label is:  8 Predcition is:  6 index is:  6826
# Label is:  8 Predcition is:  6 index is:  7578
# Label is:  8 Predcition is:  6 index is:  7882
# 20

# %%
con_train = confusion_matrix(train_dataset.df.iloc[:,0], train_predictions)
# Confusion matrix whose i-th row and j-th column entry indicates the number of samples with 
# true label being i-th class and predicted label being j-th class.
print("\nConfusion Matrix is:\n")
print(con_train,"\n")


# Class 0 is treated as Negative
tn, fp, fn, tp = con_train.ravel()

prec_test = tp/(tp+fp)
sens = tp/(tp+fn)
spec = tn/(tn+fp)

total = tp+tn+fn+fp
acc = (tp+tn)*100/total
print("Accuracy is: %", acc)

print("\nPrecision is: ", prec_test)

print("Sensitivity is: ", sens)
print("Specificity is: ", spec)


print("\nTP: ", tp, "FP: ", fp)
print("FN: ", fn, "  TN: ", tn)
# Out:
# Confusion Matrix is:
#
# [[4133    4]
#  [  16 4047]]
#
# Accuracy is: % 99.7560975609756
#
# Precision is:  0.999012589484078
# Sensitivity is:  0.9960620231356141
# Specificity is:  0.9990331157843848
#
# TP:  4047 FP:  4
# FN:  16   TN:  4133

# %%
sel = count

for i in range(sel):
    print("Image : ", i)
    print("Confidance values are : ", train_probs[train_index[i]][class1], train_probs[train_index[i]][class2])
    print("Ground Truth is: ", train_df.iloc[train_index[i],0])
    print("Predicted as: ", train_predictions[train_index[i]])

dispImage(train_df, train_index[:sel])
# Out:
# Image :  0
# Confidance values are :  0.9746061 0.023180658
# Ground Truth is:  8
# Predicted as:  6
# Image :  1
# Confidance values are :  0.79111886 0.18818808
# Ground Truth is:  8
# Predicted as:  6
# Image :  2
# Confidance values are :  0.02932633 0.9627208
# Ground Truth is:  6
# Predicted as:  8
# Image :  3
# Confidance values are :  0.8560399 0.088337295
# Ground Truth is:  8
# Predicted as:  6
# Image :  4
# Confidance values are :  0.94953716 0.03507034
# Ground Truth is:  8
# Predicted as:  6
# Image :  5
# Confidance values are :  0.850006 0.14549406
# Ground Truth is:  8
# Predicted as:  6
# Image :  6
# Confidance values are :  0.13846788 0.78335327
# Ground Truth is:  6
# Predicted as:  8
# Image :  7
# Confidance values are :  0.86777174 0.12732278
# Ground Truth is:  8
# Predicted as:  6
# Image :  8
# Confidance values are :  0.87162274 0.12095849
# Ground Truth is:  8
# Predicted as:  6
# Image :  9
# Confidance values are :  0.5578406 0.41608286
# Ground Truth is:  8
# Predicted as:  6
# Image :  10
# Confidance values are :  0.0017363694 0.9957913
# Ground Truth is:  6
# Predicted as:  8
# Image :  11
# Confidance values are :  0.8566318 0.1345713
# Ground Truth is:  8
# Predicted as:  6
# Image :  12
# Confidance values are :  0.54521143 0.4439556
# Ground Truth is:  8
# Predicted as:  6
# Image :  13
# Confidance values are :  0.94688624 0.038907543
# Ground Truth is:  8
# Predicted as:  6
# Image :  14
# Confidance values are :  0.48716193 0.50107783
# Ground Truth is:  6
# Predicted as:  8
# Image :  15
# Confidance values are :  0.66520137 0.3118945
# Ground Truth is:  8
# Predicted as:  6
# Image :  16
# Confidance values are :  0.8447114 0.14986145
# Ground Truth is:  8
# Predicted as:  6
# Image :  17
# Confidance values are :  0.9885725 0.0073411237
# Ground Truth is:  8
# Predicted as:  6
# Image :  18
# Confidance values are :  0.7322623 0.2142296
# Ground Truth is:  8
# Predicted as:  6
# Image :  19
# Confidance values are :  0.9531349 0.021605175
# Ground Truth is:  8
# Predicted as:  6

# %% [markdown]
# # Test Prediction

# %%
test_pred_df = pd.DataFrame(np.c_[np.arange(1, len(test_dataset)+1)[:,None], test_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# %%
test_prediction_df = pd.DataFrame(np.c_[np.arange(1, len(test_dataset)+1)[:,None], test_pred.numpy()], 
                      columns=['ImageId', 'Label'])

# Make a numpay array by predcited labels
test_predictions = test_prediction_df.iloc[:,1].to_numpy()
test_labels = test_y_dataset.df.iloc[:,0].to_numpy()
print(len(test_predictions), test_predictions[:10], test_labels[:10])
# Out:
# 5368 [8 6 8 8 8 8 6 8 6 6] [8 6 8 8 8 8 6 8 6 6]

# %%
test_predictions = test_prediction_df.iloc[:, 1].to_numpy()

count2 = 0
test_index = []

for i in range(len(test_predictions)):
    if test_y_dataset.df.iloc[i,0] == test_predictions[i]:
        continue
    else:
        count2 +=1
        test_index.append(i)
        print("Label is: ", test_y_dataset.y.numpy()[i], "Predcition is: ", test_predictions[i], "index is: ", i)
print(count2)
# Out:
# Label is:  6 Predcition is:  8 index is:  342
# Label is:  6 Predcition is:  8 index is:  350
# Label is:  8 Predcition is:  6 index is:  654
# Label is:  8 Predcition is:  6 index is:  673
# Label is:  8 Predcition is:  6 index is:  679
# Label is:  8 Predcition is:  6 index is:  1045
# Label is:  6 Predcition is:  8 index is:  1087
# Label is:  8 Predcition is:  6 index is:  1264
# Label is:  6 Predcition is:  8 index is:  1279
# Label is:  6 Predcition is:  8 index is:  1464
# Label is:  8 Predcition is:  6 index is:  2057
# Label is:  6 Predcition is:  8 index is:  2349
# Label is:  6 Predcition is:  8 index is:  2421
# Label is:  8 Predcition is:  6 index is:  2557
# Label is:  6 Predcition is:  8 index is:  2784
# Label is:  8 Predcition is:  6 index is:  2859
# Label is:  8 Predcition is:  6 index is:  3009
# Label is:  6 Predcition is:  8 index is:  3253
# Label is:  6 Predcition is:  8 index is:  3290
# Label is:  6 Predcition is:  8 index is:  3514
# Label is:  6 Predcition is:  8 index is:  3541
# Label is:  6 Predcition is:  8 index is:  3753
# Label is:  8 Predcition is:  6 index is:  3802
# Label is:  6 Predcition is:  8 index is:  4463
# Label is:  8 Predcition is:  6 index is:  4485
# Label is:  8 Predcition is:  6 index is:  4924
# Label is:  6 Predcition is:  8 index is:  5132
# 27

# %%
test_predictions = test_pred_df.iloc[:, 1].to_numpy()
con_test = confusion_matrix(test_dataset.df.iloc[:,0], test_predictions)
# Confusion matrix whose i-th row and j-th column entry indicates the number of samples with 
# true label being i-th class and predicted label being j-th class.
print("\nConfusion Matrix is:\n")
print(con_test,"\n")


# Class 0 is treated as Negative
tn, fp, fn, tp = con_test.ravel()

prec_test = tp/(tp+fp)
sens = tp/(tp+fn)
spec = tn/(tn+fp)

total = tp+tn+fn+fp
acc = (tp+tn)*100/total
print("Accuracy is: %", acc)

print("\nPrecision is: ", prec_test)

print("Sensitivity is: ", sens)
print("Specificity is: ", spec)


print("\nTP: ", tp, "FP: ", fp)
print("FN: ", fn, "  TN: ", tn)
# Out:
# Confusion Matrix is:
#
# [[2752   15]
#  [  12 2589]]
#
# Accuracy is: % 99.49701937406856
#
# Precision is:  0.9942396313364056
# Sensitivity is:  0.9953863898500577
# Specificity is:  0.9945789663895916
#
# TP:  2589 FP:  15
# FN:  12   TN:  2752

# %%
sel2 = count2

for i in range(sel2):
    print("Image : ", i)
    print("Confidance values are : ", test_probs[test_index[i]][class1], test_probs[test_index[i]][class2])
    print("Ground Truth is: ", test_df.iloc[test_index[i],0])
    print("Predicted as: ", test_predictions[test_index[i]])

dispImage(test_df, test_index[:sel2])
# Out:
# Image :  0
# Confidance values are :  0.07528658 0.90427554
# Ground Truth is:  6
# Predicted as:  8
# Image :  1
# Confidance values are :  0.14896373 0.8230055
# Ground Truth is:  6
# Predicted as:  8
# Image :  2
# Confidance values are :  0.9856242 0.012974239
# Ground Truth is:  8
# Predicted as:  6
# Image :  3
# Confidance values are :  0.7572636 0.21866
# Ground Truth is:  8
# Predicted as:  6
# Image :  4
# Confidance values are :  0.5934874 0.3663485
# Ground Truth is:  8
# Predicted as:  6
# Image :  5
# Confidance values are :  0.62930006 0.35224146
# Ground Truth is:  8
# Predicted as:  6
# Image :  6
# Confidance values are :  0.10493399 0.8837302
# Ground Truth is:  6
# Predicted as:  8
# Image :  7
# Confidance values are :  0.5858169 0.40787107
# Ground Truth is:  8
# Predicted as:  6
# Image :  8
# Confidance values are :  0.28929442 0.7007266
# Ground Truth is:  6
# Predicted as:  8
# Image :  9
# Confidance values are :  0.23208076 0.7537407
# Ground Truth is:  6
# Predicted as:  8
# Image :  10
# Confidance values are :  0.9714101 0.02104567
# Ground Truth is:  8
# Predicted as:  6
# Image :  11
# Confidance values are :  0.05325914 0.9350104
# Ground Truth is:  6
# Predicted as:  8
# Image :  12
# Confidance values are :  0.005672873 0.985151
# Ground Truth is:  6
# Predicted as:  8
# Image :  13
# Confidance values are :  0.65765655 0.30104902
# Ground Truth is:  8
# Predicted as:  6
# Image :  14
# Confidance values are :  0.02730266 0.9570061
# Ground Truth is:  6
# Predicted as:  8
# Image :  15
# Confidance values are :  0.7032489 0.2765325
# Ground Truth is:  8
# Predicted as:  6
# Image :  16
# Confidance values are :  0.77552485 0.19831984
# Ground Truth is:  8
# Predicted as:  6
# Image :  17
# Confidance values are :  0.007819382 0.98366195
# Ground Truth is:  6
# Predicted as:  8
# Image :  18
# Confidance values are :  0.20290473 0.7617999
# Ground Truth is:  6
# Predicted as:  8
# Image :  19
# Confidance values are :  0.072589085 0.8951464
# Ground Truth is:  6
# Predicted as:  8
# Image :  20
# Confidance values are :  0.009860211 0.9843816
# Ground Truth is:  6
# Predicted as:  8
# Image :  21
# Confidance values are :  0.1377168 0.8465916
# Ground Truth is:  6
# Predicted as:  8
# Image :  22
# Confidance values are :  0.52610743 0.45983747
# Ground Truth is:  8
# Predicted as:  6
# Image :  23
# Confidance values are :  0.15739068 0.8191801
# Ground Truth is:  6
# Predicted as:  8
# Image :  24
# Confidance values are :  0.5885186 0.37631735
# Ground Truth is:  8
# Predicted as:  6
# Image :  25
# Confidance values are :  0.6890742 0.2981005
# Ground Truth is:  8
# Predicted as:  6
# Image :  26
# Confidance values are :  0.08787664 0.89453876
# Ground Truth is:  6
# Predicted as:  8

# %%
npv = tn/(tn+fn)
print(npv)
# Out:
# 0.9956584659913169
